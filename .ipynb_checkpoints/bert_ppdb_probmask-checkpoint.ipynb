# %%
from __future__ import absolute_import, division, print_function

import argparse
import csv
import logging
import os
import random
import math
import sys
import re

from pytorch_pretrained_bert.tokenization import BertTokenizer
from pytorch_pretrained_bert.modeling import BertModel, BertForMaskedLM

from sklearn.metrics.pairwise import cosine_similarity as cosine

from scipy.special import softmax

import openpyxl

from pathlib import Path

from PPDB import Ppdb
from nltk.tokenize import word_tokenize

# OPTIONAL: if you want to have more information on what's happening, activate the logger as follows
import numpy as np
import torch
import nltk
#from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

from collections import defaultdict

from torch.utils.data import (DataLoader, RandomSampler, SequentialSampler,
                              TensorDataset)
from torch.utils.data.distributed import DistributedSampler
from tqdm import tqdm, trange
from pytorch_pretrained_bert.optimization import BertAdam, WarmupLinearSchedule

from pytorch_pretrained_bert.file_utils import PYTORCH_PRETRAINED_BERT_CACHE, WEIGHTS_NAME, CONFIG_NAME

import logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
class InputFeatures(object):
    """A single set of features of data."""

    def __init__(self, unique_id, tokens, input_ids, input_mask, input_type_ids):
        self.unique_id = unique_id
        self.tokens = tokens
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.input_type_ids = input_type_ids

def convert_sentence_to_token(sentence, seq_length, tokenizer):
  
    tokenized_text = tokenizer.tokenize(sentence)

    if len(tokenized_text) > seq_length - 2:
        tokenized_text = tokenized_text[0:(seq_length - 2)]

    position =[]
    special =[]
    isSpecial = False

    whole_word = ''
    words = []

    start_pos =  len(tokenized_text)  + 2

    connect_sign = 0
    for index in range(len(tokenized_text)-1):
        
        if(tokenized_text[index+1]=="-" and tokenized_text[index+2]!="-"):
            
            whole_word += tokenized_text[index]
            special.append(start_pos+index)
            continue

        if(tokenized_text[index]=="-"):
            
            whole_word += tokenized_text[index]
            special.append(start_pos+index)

            if(tokenized_text[index-1]=="-"):
                words.append(whole_word)
                position.append(special)
                special = []
                whole_word = ''
            continue

        if(tokenized_text[index]!="-" and tokenized_text[index-1]=="-"):
            whole_word += tokenized_text[index]
            words.append(whole_word)
            whole_word = ''
            special.append(start_pos+index)
            position.append(special)
            special = []
            continue    

        if(tokenized_text[index+1][0:2]=="##"):
            special.append(start_pos+index)
            whole_word += tokenized_text[index]
            isSpecial = True
            continue
        else:
            if isSpecial:
                isSpecial = False
                special.append(start_pos+index)
                position.append(special)
                whole_word += tokenized_text[index]
                whole_word = whole_word.replace('##','')
                words.append(whole_word)
                whole_word = ''
                special =  []
            else:
                position.append(start_pos+index)
                words.append(tokenized_text[index])

    if isSpecial:
        isSpecial = False
        special.append(start_pos+index+1)
        position.append(special)
        whole_word += tokenized_text[index+1]
        whole_word = whole_word.replace('##','')
        words.append(whole_word)
    else:
        position.append(start_pos+index+1)
        words.append(tokenized_text[index+1])
       
    return tokenized_text, words, position

def convert_whole_word_to_feature(tokens_a, mask_position, seq_length, tokenizer, prob_mask):
    """Loads a data file into a list of `InputFeature`s."""

    #tokens_a = tokenizer.tokenize(sentence)
    #print(mask_position)
    #print("Convert_whole_word_to_feature")
    #print(tokens_a)

    tokens = []
    input_type_ids = []
    tokens.append("[CLS]")
    input_type_ids.append(0)


    class ClassName(object):


    	"""docstring for ClassName"""



    	def __init__(self, arg):

    		super(ClassName, self).__init__()


    		self.arg = arg

    		

    
    len_tokens = len(tokens_a)
    first_sentence_mask_random = random.sample(range(0,len_tokens), int(prob_mask*len_tokens))

    mask_index = []

    for mask_pos in mask_position:
        mask_index.append(mask_pos-len_tokens-2)

    for i in range(len_tokens):

        if i in mask_index:
            tokens.append(tokens_a[i])
        elif i in first_sentence_mask_random:
            tokens.append('[MASK]')
        else:
            tokens.append(tokens_a[i])
        input_type_ids.append(0)
    
    tokens.append("[SEP]")
    input_type_ids.append(0)

    for token in tokens_a:
        tokens.append(token)
        input_type_ids.append(1)

    tokens.append("[SEP]")
    input_type_ids.append(1)

    true_word = ''
    index = 0
    count = 0
    mask_position_length = len(mask_position)

    while count in range(mask_position_length):
        index = mask_position_length - 1 - count

        pos = mask_position[index]
        if index == 0:
            tokens[pos] = '[MASK]'
        else:
            del tokens[pos]
            del input_type_ids[pos]

        count += 1

    #print(tokens)

    input_ids = tokenizer.convert_tokens_to_ids(tokens)

        # The mask has 1 for real tokens and 0 for padding tokens. Only real
        # tokens are attended to.
    input_mask = [1] * len(input_ids)

        # Zero-pad up to the sequence length.
    while len(input_ids) < seq_length:
        input_ids.append(0)
        input_mask.append(0)
        input_type_ids.append(0)

    assert len(input_ids) == seq_length
    assert len(input_mask) == seq_length
    assert len(input_type_ids) == seq_length

      
    return InputFeatures(unique_id=0,  tokens=tokens, input_ids=input_ids,input_mask=input_mask,input_type_ids=input_type_ids)
    

def convert_token_to_feature(tokens_a, mask_position, seq_length, tokenizer, prob_mask):
    """Loads a data file into a list of `InputFeature`s."""

    #tokens_a = tokenizer.tokenize(sentence)
    #print(mask_position)
    #print("----------")
    #print(tokens_a)

    tokens = []
    input_type_ids = []
    tokens.append("[CLS]")
    input_type_ids.append(0)

    len_tokens = len(tokens_a)
    #print("length of tokens: ", len_tokens)

    first_sentence_mask_random = random.sample(range(0,len_tokens), int(prob_mask*len_tokens))

    for i in range(len_tokens):

        if i==(mask_position-len_tokens-2):
            tokens.append(tokens_a[i])
        elif i in first_sentence_mask_random:
            tokens.append('[MASK]')
        else:
            tokens.append(tokens_a[i])
        input_type_ids.append(0)
    
    tokens.append("[SEP]")
    input_type_ids.append(0)

    for token in tokens_a:
        tokens.append(token)
        input_type_ids.append(1)

    tokens.append("[SEP]")
    input_type_ids.append(1)

    true_word = ''
    true_word = tokens[mask_position]
    tokens[mask_position] =  '[MASK]'

    #print(tokens)

    input_ids = tokenizer.convert_tokens_to_ids(tokens)

        # The mask has 1 for real tokens and 0 for padding tokens. Only real
        # tokens are attended to.
    input_mask = [1] * len(input_ids)

        # Zero-pad up to the sequence length.
    while len(input_ids) < seq_length:
        input_ids.append(0)
        input_mask.append(0)
        input_type_ids.append(0)

    assert len(input_ids) == seq_length
    assert len(input_mask) == seq_length
    assert len(input_type_ids) == seq_length

      
    return InputFeatures(unique_id=0,  tokens=tokens, input_ids=input_ids,input_mask=input_mask,input_type_ids=input_type_ids)
    

def getWordmap(wordVecPath):
    words=[]
    We = []
    f = open(wordVecPath,'r', encoding="utf-8")
    lines = f.readlines()

    for (n,line) in enumerate(lines):
        if (n == 0) :
            print(line)
            continue
        word, vect = line.rstrip().split(' ', 1)
                    
        vect = np.fromstring(vect, sep=' ')
                
        We.append(vect)

        words.append(word)

        #if(n==200000):
        #    break
    f.close()       
    return (words, We)


def getWordCount(word_count_path):
    word2count = {}
    xlsx_file = Path('',word_count_path)
    wb_obj = openpyxl.load_workbook(xlsx_file)
    sheet = wb_obj.active

    last_column = sheet.max_column-1
    for i, row in enumerate(sheet.iter_rows(values_only=True)):
        if i==0:
            continue
        word2count[row[0]] = round(float(row[last_column]),3)
        
    return word2count

def read_eval_index_dataset(data_path, is_label=True):
    sentences=[]
    mask_words = []
    mask_labels = []

    with open(data_path, "r", encoding='ISO-8859-1') as reader:
        while True:
            line = reader.readline()
            
            if not line:
                break
            
            sentence,words = line.strip().split('\t',1)
                #print(sentence)
            mask_word,labels = words.strip().split('\t',1)
            label = labels.split('\t')
                
            sentences.append(sentence)
            mask_words.append(mask_word)
                
            one_labels = []
            for la in label[1:]:
                if la not in one_labels:
                    la_id,la_word = la.split(':')
                    one_labels.append(la_word)
                
                #print(mask_word, " ---",one_labels)
            mask_labels.append(one_labels)
            
    return sentences,mask_words,mask_labels

def read_eval_dataset(data_path, is_label=True):
    sentences=[]
    mask_words = []
    mask_labels = []
    id = 0

    with open(data_path, "r", encoding='ISO-8859-1') as reader:
        while True:
            line = reader.readline()
            if is_label:
                id += 1
                if id==1:
                    continue
                if not line:
                    break
                sentence,words = line.strip().split('\t',1)
                #print(sentence)
                mask_word,labels = words.strip().split('\t',1)
                label = labels.split('\t')
                
                sentences.append(sentence)
                mask_words.append(mask_word)
                
                one_labels = []
                for la in label:
                    if la not in one_labels:
                        one_labels.append(la)
                
                #print(mask_word, " ---",one_labels)
                    
                mask_labels.append(one_labels)
            else:
                if not line:
                    break
                #print(line)
                sentence,mask_word = line.strip().split('\t')
                sentences.append(sentence)
                mask_words.append(mask_word)
    return sentences,mask_words,mask_labels

def BERT_candidate_generation(source_word, pre_tokens, pre_scores, ps, num_selection=10):

    cur_tokens=[]
   

    source_stem = ps.stem(source_word)

    assert num_selection<=len(pre_tokens)

    for i in range(len(pre_tokens)):
        token = pre_tokens[i]
     
        if token[0:2]=="##":
            continue

        if(token==source_word):
            continue

        token_stem = ps.stem(token)

        if(token_stem == source_stem):
            continue

        if (len(token_stem)>=3) and (token_stem[:3]==source_stem[:3]):
            continue

        cur_tokens.append(token)
        

        if(len(cur_tokens)==num_selection):
            break
    
    if(len(cur_tokens)==0):
        cur_tokens = pre_tokens[0:num_selection+1]
        

    assert len(cur_tokens)>0       

    return cur_tokens

def cross_entropy_word(X,i,pos):
    
    #print(X)
    #print(X[0,2,3])
    X = softmax(X,axis=1)
    loss = 0
    loss -= np.log10(X[i,pos])
    return loss


def get_score(sentence,tokenizer,maskedLM):
    tokenize_input = tokenizer.tokenize(sentence)

    len_sen = len(tokenize_input)

    START_TOKEN = '[CLS]'
    SEPARATOR_TOKEN = '[SEP]'

    tokenize_input.insert(0, START_TOKEN)
    tokenize_input.append(SEPARATOR_TOKEN)

    input_ids = tokenizer.convert_tokens_to_ids(tokenize_input)

    #tensor_input = torch.tensor([tokenizer.convert_tokens_to_ids(tokenize_input)])
    #print("tensor_input")
    #print(tensor_input)
    #tensor_input = tensor_input.to('cuda')
    sentence_loss = 0
    
    for i,word in enumerate(tokenize_input):

        if(word == START_TOKEN or word==SEPARATOR_TOKEN):
            continue

        orignial_word = tokenize_input[i]
        tokenize_input[i] = '[MASK]'
        #print(tokenize_input)
        mask_input = torch.tensor([tokenizer.convert_tokens_to_ids(tokenize_input)])
        #print(mask_input)
        mask_input = mask_input.to('cuda')
        with torch.no_grad():
            att, pre_word =maskedLM(mask_input)
        word_loss = cross_entropy_word(pre_word[0].cpu().numpy(),i,input_ids[i])
        sentence_loss += word_loss
        #print(word_loss)
        tokenize_input[i] = orignial_word
        
    return np.exp(sentence_loss/len_sen)


def LM_score(source_word,source_context,substitution_selection,tokenizer,maskedLM):
    #source_index = source_context.index(source_word)

    source_sentence = ''

    for context in source_context:
        source_sentence += context + " "
    
    source_sentence = source_sentence.strip()
    #print(source_sentence)
    LM = []

    source_loss = get_score(source_sentence,tokenizer,maskedLM)

    for substibution in substitution_selection:
        
        sub_sentence = source_sentence.replace(source_word,substibution)

        
        #print(sub_sentence)
        score = get_score(sub_sentence,tokenizer,maskedLM)

        #print(score)
        LM.append(score)

    return LM,source_loss


def preprocess_SR(source_word, substitution_selection, fasttext_dico, fasttext_emb, word_count):
    ss = []
    ##ss_score=[]
    sis_scores=[]
    count_scores=[]

    isFast = True

    if(source_word not in fasttext_dico):
        isFast = False
    else:
        source_emb = fasttext_emb[fasttext_dico.index(source_word)].reshape(1,-1)

    #ss.append(source_word)

    for sub in substitution_selection:

        if sub not in word_count:
            continue
        else:
            sub_count = word_count[sub]

        if(sub_count<=3):
            continue

        #if sub_count<source_count:
         #   continue
        if isFast:
            if sub not in fasttext_dico:
                continue

            token_index_fast = fasttext_dico.index(sub)
            sis = cosine(source_emb, fasttext_emb[token_index_fast].reshape(1,-1))

            #if sis<0.35:
            #    continue
            sis_scores.append(sis)

        ss.append(sub)
        count_scores.append(sub_count)

    return ss,sis_scores,count_scores

def compute_context_sis_score(source_word, sis_context, substitution_selection, fasttext_dico, fasttext_emb):
    context_sis = []

    word_context = []

    

    for con in sis_context:
        if con==source_word or (con not in fasttext_dico):
            continue

        word_context.append(con)

    if len(word_context)!=0:
        for sub in substitution_selection:
            sub_emb = fasttext_emb[fasttext_dico.index(sub)].reshape(1,-1)
            all_sis = 0
            for con in word_context:
                token_index_fast = fasttext_dico.index(con)
                all_sis += cosine(sub_emb, fasttext_emb[token_index_fast].reshape(1,-1))

            context_sis.append(all_sis/len(word_context))
    else:
        for i in range(len(substitution_selection)):
            context_sis.append(len(substitution_selection)-i)

            
    return context_sis


def substitution_ranking(source_word, source_context, substitution_selection, fasttext_dico, fasttext_emb, word_count, ssPPDB, tokenizer, maskedLM, lables):

    ss,sis_scores,count_scores=preprocess_SR(source_word, substitution_selection, fasttext_dico, fasttext_emb, word_count)

    #print(ss)
    if len(ss)==0:
        return source_word

    if len(sis_scores)>0:
        seq = sorted(sis_scores,reverse = True )
        sis_rank = [seq.index(v)+1 for v in sis_scores]
    
    rank_count = sorted(count_scores,reverse = True )
    
    count_rank = [rank_count.index(v)+1 for v in count_scores]
  
    lm_score,source_lm = LM_score(source_word,source_context,ss,tokenizer,maskedLM)

    rank_lm = sorted(lm_score)
    lm_rank = [rank_lm.index(v)+1 for v in lm_score]
    

    bert_rank = []
    ppdb_rank =[]
    for i in range(len(ss)):
        bert_rank.append(i+1)

        if ss[i] in ssPPDB:
        	ppdb_rank.append(1)
        else:
        	ppdb_rank.append(len(ss)/3)

    if len(sis_scores)>0:
        all_ranks = [bert+sis+count+LM+ppdb  for bert,sis,count,LM,ppdb in zip(bert_rank,sis_rank,count_rank,lm_rank,ppdb_rank)]
    else:
        all_ranks = [bert+count+LM+ppdb  for bert,count,LM,ppdb in zip(bert_rank,count_rank,lm_rank,ppdb_rank)]
    #all_ranks = [con for con in zip(context_rank)]


    pre_index = all_ranks.index(min(all_ranks))

    #return ss[pre_index]

    pre_count = count_scores[pre_index]

    if source_word in word_count:
    	source_count = word_count[source_word]
    else:
    	source_count = 0

    pre_lm = lm_score[pre_index]

    #print(lm_score)
    #print(source_lm)
    #print(pre_lm)


    #pre_word = ss[pre_index]


    if source_lm>pre_lm or pre_count>source_count:
    	pre_word = ss[pre_index]
    else:
    	pre_word = source_word

    return pre_word


def evaulation_SS_scores(ss,labels):
    assert len(ss)==len(labels)

    potential = 0
    instances = len(ss)
    precision = 0
    precision_all = 0
    recall = 0
    recall_all = 0

    for i in range(len(ss)):

        one_prec = 0
        
        common = list(set(ss[i]).intersection(labels[i]))

        if len(common)>=1:
            potential +=1
        precision += len(common)
        recall += len(common)
        precision_all += len(ss[i])
        recall_all += len(labels[i])

    potential /=  instances
    precision /= precision_all
    recall /= recall_all
    F_score = 2*precision*recall/(precision+recall)

    return potential,precision,recall,F_score


def evaulation_pipeline_scores(substitution_words,source_words,gold_words):

    instances = len(substitution_words)
    precision = 0
    accuracy = 0
    changed_proportion = 0

    for sub, source, gold in zip(substitution_words,source_words,gold_words):
        if sub==source or (sub in gold):
            precision += 1
        if sub!=source and (sub in gold):
            accuracy += 1
        if sub!=source:
            changed_proportion += 1

    return precision/instances,accuracy/instances,changed_proportion/instances




def extract_context(words, mask_index, window):
    #extract 7 words around the content word

    length = len(words)

    half = int(window/2)

    assert mask_index>=0 and mask_index<length

    context = ""

    if length<=window:
        context = words
    elif mask_index<length-half and mask_index>=half:
        context = words[mask_index-half:mask_index+half+1]
    elif mask_index<half:
        context = words[0:window]
    elif mask_index>=length-half:
        context = words[length-window:length]
    else:
        print("Wrong!")

    return context

def preprocess_tag(tag):
    if tag[0] =="V" or tag[0]=="N":
        return tag
    if tag[0]=="R":
        return "r"
    if tag[0]=="J" or tag[0]=="I":
        return 'a'
    else:
        return 's'

# %%
parser = argparse.ArgumentParser()

parser.add_argument("--eval_dir",
                        default=None,
                        type=str,
                        help="The evaluation data dir.")
parser.add_argument("--bert_model", default=None, type=str,
                        help="Bert pre-trained model selected in the list: bert-base-uncased, "
                        "bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, "
                        "bert-base-multilingual-cased, bert-base-chinese.")

parser.add_argument("--output_SR_file",
                        default=None,
                        type=str,
                        help="The output directory of writing substitution selection.")
parser.add_argument("--word_embeddings",
                        default=None,
                        type=str,
                        help="The path of word embeddings")
parser.add_argument("--word_frequency",
                        default=None,
                        type=str,
                        help="The path of word frequency.")
    
parser.add_argument("--ppdb",
                        default="./ppdb-2.0-tldr",
                        type=str,
                        help="The path of word frequency.")

parser.add_argument("--prob_mask",
                        default=0,
                        type=float,
                        help="Proportion of the masked words in first sentence. "
                             "E.g., 0.1 = 10%% of training.")



## Other parameters
parser.add_argument("--cache_dir",
                        default="",
                        type=str,
                        help="Where do you want to store the pre-trained models downloaded from s3")

parser.add_argument("--max_seq_length",
                        default=128,
                        type=int,
                        help="The maximum total input sequence length after WordPiece tokenization. \n"
                             "Sequences longer than this will be truncated, and sequences shorter \n"
                             "than this will be padded.")

parser.add_argument("--do_eval",
                        action='store_true',
                        help="Whether to run eval on the dev set.")
parser.add_argument("--do_lower_case",
                        action='store_true',
                        help="Set this flag if you are using an uncased model.")

parser.add_argument("--eval_batch_size",
                        default=8,
                        type=int,
                        help="Total batch size for eval.")
parser.add_argument("--num_selections",
                        default=20,
                        type=int,
                        help="Total number of training epochs to perform.")
parser.add_argument("--num_eval_epochs",
                        default=1,
                        type=int,
                        help="Total number of training epochs to perform.")



parser.add_argument("--warmup_proportion",
                        default=0.1,
                        type=float,
                        help="Proportion of training to perform linear learning rate warmup for. "
                             "E.g., 0.1 = 10%% of training.")
parser.add_argument("--no_cuda",
                        action='store_true',
                        help="Whether not to use CUDA when available")
parser.add_argument("--local_rank",
                        type=int,
                        default=-1,
                        help="local_rank for distributed training on gpus")
parser.add_argument('--seed',
                        type=int,
                        default=42,
                        help="random seed for initialization")
parser.add_argument('--fp16',
                        action='store_true',
                        help="Whether to use 16-bit float precision instead of 32-bit")
parser.add_argument('--loss_scale',
                        type=float, default=0,
                        help="Loss scaling to improve fp16 numeric stability. Only used when fp16 set to True.\n"
                             "0 (default value): dynamic loss scaling.\n"
                             "Positive power of 2: static loss scaling value.\n")
parser.add_argument('--server_ip', type=str, default='', help="Can be used for distant debugging.")
parser.add_argument('--server_port', type=str, default='', help="Can be used for distant debugging.")
args = parser.parse_args([])

# %%
if args.server_ip and args.server_port:
    import ptvsd
    print("Waiting for debugger attach")
    ptvsd.enable_attach(address=(args.server_ip, args.server_port), redirect_output=True)
    ptvsd.wait_for_attach()


if args.local_rank == -1 or args.no_cuda:
    device = torch.device("cuda" if torch.cuda.is_available() and not args.no_cuda else "cpu")
    n_gpu = torch.cuda.device_count()
else:
    torch.cuda.set_device(args.local_rank)
    device = torch.device("cuda", args.local_rank)
    n_gpu = 1
    # Initializes the distributed backend which will take care of sychronizing nodes/GPUs
    torch.distributed.init_process_group(backend='nccl')

logging.basicConfig(format = '%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt = '%m/%d/%Y %H:%M:%S',
                    level = logging.INFO if args.local_rank in [-1, 0] else logging.WARN)

logger.info("device: {} n_gpu: {}, distributed training: {}, 16-bits training: {}".format(
    device, n_gpu, bool(args.local_rank != -1), args.fp16))


random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
if n_gpu > 0:
    torch.cuda.manual_seed_all(args.seed)

if not args.do_eval:
    raise ValueError("At least `do_eval` must be True.")

tokenizer = BertTokenizer.from_pretrained(args.bert_model, do_lower_case=args.do_lower_case)

train_examples = None
num_train_optimization_steps = None
    

# Prepare model
cache_dir = args.cache_dir if args.cache_dir else os.path.join(str(PYTORCH_PRETRAINED_BERT_CACHE), 'distributed_{}'.format(args.local_rank))
model = BertForMaskedLM.from_pretrained(args.bert_model,output_attentions=True,cache_dir=cache_dir)
if args.fp16:
    model.half()
model.to(device)

output_sr_file = open(args.output_SR_file,"a+")
# Out:
# INFO:__main__:device: cuda n_gpu: 1, distributed training: False, 16-bits training: False
# INFO:pytorch_pretrained_bert.tokenization:loading vocabulary file D:/data/bert_ppdb/bert-large-uncased-whole-word-masking-vocab.txt
# INFO:pytorch_pretrained_bert.modeling:loading weights file D:/data/bert_ppdb/bert-large-uncased-whole-word-masking-pytorch_model.bin
# INFO:pytorch_pretrained_bert.modeling:loading configuration file D:/data/bert_ppdb/bert-large-uncased-whole-word-masking-config.json
# INFO:pytorch_pretrained_bert.modeling:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "type_vocab_size": 2,
#   "vocab_size": 30522
# }
#
# INFO:pytorch_pretrained_bert.modeling:Weights from pretrained model not used in BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']

# %%
print("Loading embeddings ...")

wordVecPath = args.word_embeddings
#wordVecPath = "/media/qiang/ee63f41d-4004-44fe-bcfd-522df9f2eee8/glove.840B.300d.txt"

fasttext_dico, fasttext_emb = getWordmap(wordVecPath)

#stopword = set(stopwords.words('english'))
word_count_path = args.word_frequency
#word_count_path = "word_frequency_wiki.txt"
word_count = getWordCount(word_count_path)

ps = PorterStemmer()
# Out:
# Loading embeddings ...
# 2000000 300

# %%
args.do_eval=True
args.do_lower_case=True
args.num_selections=10
args.prob_mask=0.5
args.eval_dir='D:/data/bert_ppdb/datasets/lex.mturk.txt'
args.bert_model='bert-large-uncased-whole-word-masking'
args.max_seq_length=250
args.word_embeddings='D:/data/bert_ppdb/crawl-300d-2M-subword.vec'
args.word_frequency='D:/data/bert_ppdb/SUBTLEX_frequency.xlsx'
args.ppdb='D:/data/bert_ppdb/ppdb-2.0-tldr'
args.output_SR_file='D:/data/bert_ppdb/results/NNSeval'

# %%
print("loading PPDB ...")
ppdb_path = args.ppdb
ppdb_model = Ppdb(ppdb_path)
# Out:
# loading PPDB ...

# %%
if args.do_eval and (args.local_rank == -1 or torch.distributed.get_rank() == 0):
    fileName = args.eval_dir.split('/')[-1][:-4]
    if fileName=='lex.mturk':
        eval_examples, mask_words, mask_labels = read_eval_dataset(args.eval_dir)
    else:
        eval_examples, mask_words, mask_labels = read_eval_index_dataset(args.eval_dir)

       
    logger.info("***** Running evaluation *****")
    logger.info("  Num examples = %d", len(eval_examples))
    #logger.info("  Batch size = %d", args.eval_batch_size)
# Out:
# INFO:__main__:***** Running evaluation *****
# INFO:__main__:  Num examples = 500

# %%
for mask_num in range(1):
    args.prob_mask=0
    print('args.prob_mask ',args.prob_mask)
    for num in range(1):
        args.seed=num*10+5
        print('args.seed',args.seed)
        print('第 ',num+1,'次循环')
    
        CGBERT = []
        CSBERT = []
        SS = []
        substitution_words = []
        num_selection = args.num_selections
        bre_i=0
        window_context = 11
        
        model.eval()
        eval_size = len(eval_examples)

        for i in range(eval_size):
            if (i%100==0):
                print(i)
            tokens, words, position = convert_sentence_to_token(eval_examples[i], args.max_seq_length, tokenizer)

            assert len(words)==len(position)

            mask_index = words.index(mask_words[i])

            mask_context = extract_context(words,mask_index,window_context)

            len_tokens = len(tokens)

            mask_position = position[mask_index]
            if isinstance(mask_position,list):
                feature = convert_whole_word_to_feature(tokens, mask_position, args.max_seq_length, tokenizer, args.prob_mask)
            else:
                feature = convert_token_to_feature(tokens, mask_position, args.max_seq_length, tokenizer, args.prob_mask)

            tokens_tensor = torch.tensor([feature.input_ids])

            token_type_ids = torch.tensor([feature.input_type_ids])

            attention_mask = torch.tensor([feature.input_mask])
    
            tokens_tensor = tokens_tensor.to('cuda')
            token_type_ids = token_type_ids.to('cuda')
            attention_mask = attention_mask.to('cuda')

            # Predict all tokens
            with torch.no_grad():
                all_attentions,prediction_scores = model(tokens_tensor, token_type_ids,attention_mask)


            
            if isinstance(mask_position,list):
                predicted_top = prediction_scores[0, mask_position[0]].topk(80)
            else:
                predicted_top = prediction_scores[0, mask_position].topk(80)
                #print(predicted_top[0].cpu().numpy())
            pre_tokens = tokenizer.convert_ids_to_tokens(predicted_top[1].cpu().numpy())
            
            #print(predicted_top[0].cpu().numpy())

            sentence = eval_examples[i].lower()
            words = word_tokenize(sentence)

            words_tag = nltk.pos_tag(words)

            complex_word_index = words.index(mask_words[i])

            complex_word_tag = words_tag[complex_word_index][1]

            #print(complex_word_tag)

            complex_word_tag = preprocess_tag(complex_word_tag)
            #print(complex_word_tag)

            #mask_context = extract_context(words,complex_word_index,window_context)

            #break
            #print(mask_words[i])
            #cgPPDB,csPPDB = PPDB_candidate_generation(mask_words[i],complex_word_tag, ppdb_model, ps, word_count, 30)
            cgPPDB = ppdb_model.predict(mask_words[i],complex_word_tag)

            #if(len(cgPPDB)>30):
            #cgPPDB=cgPPDB[:30]

            #break
            cgBERT = BERT_candidate_generation(mask_words[i], pre_tokens, predicted_top[0].cpu().numpy(), ps, args.num_selections)
            print('cgBERT',cgBERT)
            CGBERT.append(cgBERT)


            pre_word = substitution_ranking(mask_words[i], mask_context, cgBERT, fasttext_dico, fasttext_emb,word_count,cgPPDB,tokenizer,model,mask_labels[i])

            substitution_words.append(pre_word)
            
        print('第 ',num+1,'次循环')
        print('args.prob_mask ',args.prob_mask)
        potential,precision,recall,F_score=evaulation_SS_scores(CGBERT, mask_labels)
        print("The score of evaluation for BERT candidate generation")
        print(potential,precision,recall,F_score)

        

        precision,accuracy,changed_proportion=evaulation_pipeline_scores(substitution_words, mask_words, mask_labels)
        print("The score of evaluation for full LS pipeline")
        print(precision,accuracy,changed_proportion)

print('end')
        #output_sr_file.close()
# Out:
# args.prob_mask  0
# args.seed 5
# 第  1 次循环
# 0
# cgBERT ['parts', 'components', 'features', 'chunks', 'details', 'elements', 'bits', 'sections', 'chips', 'code']
# cgBERT ['reclaimed', 'pumped', 'derived', 'routed', 'transferred', 'wasted', 'recycled', 'converted', 'displaced', 'reserved']
# cgBERT ['owner', 'proprietor', 'host', 'recipient', 'holder', 'master', 'bearer', 'tenant', 'inventor', 'successor']
# cgBERT ['dangers', 'complications', 'risks', 'traps', 'devices', 'difficulties', 'types', 'escapes', 'methods', 'situations']
# cgBERT ['maintained', 'remained', 'kept', 'conserved', 'held', 'sustained', 'exhibited', 'continued', 'preserved', 'regained']
# cgBERT ['home', 'seat', 'house', 'mansion', 'housing', 'haven', 'property', 'palace', 'pursuit', 'possession']
# cgBERT ['obtained', 'secured', 'prepared', 'plucked', 'selected', 'acquired', 'harvested', 'derived', 'picked', 'gathered']
# cgBERT ['summoned', 'hosted', 'assembled', 'scheduled', 'held', 'presided', 'commissioned', 'chaired', 'petitioned', 'formulated']
# cgBERT ['essential', 'crucial', 'fundamental', 'critical', 'relevant', 'important', 'beneficial', 'basic', 'necessary', 'significant']
# cgBERT ['obtained', 'gained', 'purchased', 'accumulated', 'attained', 'secured', 'amassed', 'earned', 'bought', 'established']
# cgBERT ['amount', 'prevalence', 'quantity', 'occurrence', 'population', 'amounts', 'accumulation', 'concentrations', 'concentration', 'availability']
# cgBERT ['significant', 'large', 'considerable', 'massive', 'sufficient', 'certain', 'sizable', 'extensive', 'excessive', 'heavy']
# cgBERT ['dry', 'extreme', 'alternative', 'harsh', 'desert', 'alternate', 'ancient', 'open', 'exotic', 'old']
# cgBERT ['drifted', 'wandered', 'travelled', 'curved', 'continued', 'traveled', 'tracked', 'raced', 'moved', 'floated']
# cgBERT ['produced', 'provided', 'created', 'gave', 'attracted', 'caused', 'producing', 'charged', 'had', 'manufactured']
# cgBERT ['constitute', 'contain', 'collect', 'form', 'construct', 'encompass', 'assemble', 'aggregate', 'consist', 'consume']
# cgBERT ['guarantees', 'ensures', 'facilitates', 'supports', 'maintains', 'holds', 'prevents', 'helps', 'confines', 'protects']
# cgBERT ['history', 'life', 'work', 'success', 'lifetime', 'year', 'retirement', 'profession', 'period', 'comeback']
# cgBERT ['insists', 'declines', 'decides', 'threatens', 'continues', 'agrees', 'accepts', 'yields', 'leaves', 'demands']
# cgBERT ['losses', 'fatalities', 'civilians', 'deaths', 'injuries', 'ratings', 'survivors', 'memorials', 'attendants', 'incidents']
# cgBERT ['broadcasting', 'sending', 'delivering', 'communicating', 'providing', 'distributing', 'conducting', 'displaying', 'passing', 'presenting']
# cgBERT ['published', 'opened', 'issued', 'sold', 'launched', 'available', 'announced', 'out', 'written', 'discovered']
# cgBERT ['situations', 'occasions', 'conditions', 'cases', 'times', 'contexts', 'instances', 'surroundings', 'scenarios', 'environments']
# cgBERT ['ceased', 'retired', 'formed', 'divorced', 'faltered', 'resigned', 'reformed', 'terminated', 'cancelled', 'contracted']
# cgBERT ['regarded', 'intended', 'anticipated', 'identified', 'imagined', 'realised', 'indicated', 'contemplated', 'arranged', 'examined']
# cgBERT ['body', 'chassis', 'layout', 'backbone', 'hull', 'platform', 'fabric', 'structure', 'frame', 'cockpit']
# cgBERT ['absorption', 'purchase', 'ownership', 'interception', 'takeover', 'administration', 'enrollment', 'unification', 'merger', 'owner']
# cgBERT ['approved', 'adopted', 'sanctioned', 'supported', 'ratified', 'backed', 'sponsored', 'accepted', 'upheld', 'accredited']
# cgBERT ['fringe', 'rim', 'quadrant', 'coastline', 'heartland', 'edges', 'outskirts', 'verge', 'radius', 'edge']
# cgBERT ['acceptable', 'permitted', 'desirable', 'useful', 'allowed', 'accepted', 'beneficial', 'welcome', 'encouraged', 'welcomed']
# cgBERT ['furious', 'outraged', 'aggravated', 'angry', 'angered', 'agitated', 'appalled', 'impatient', 'alarmed', 'crazed']
# cgBERT ['effort', 'mission', 'operation', 'enterprise', 'excursion', 'affair', 'trip', 'voyage', 'attempt', 'campaign']
# cgBERT ['positioned', 'lodged', 'centred', 'located', 'placed', 'constituted', 'erected', 'nowadays', 'disposed', 'constructed']
# cgBERT ['commitments', 'responsibilities', 'duties', 'commitment', 'ties', 'requirements', 'contracts', 'payments', 'debts', 'allegiance']
# cgBERT ['obscure', 'unclear', 'uncertain', 'vague', 'unspecified', 'oblique', 'unknown', 'undisclosed', 'cryptic', 'elusive']
# cgBERT ['leased', 'pledged', 'surrendered', 'conceded', 'transferred', 'donated', 'relinquished', 'granted', 'bequeathed', 'yielded']
# cgBERT ['blockade', 'garrison', 'bombardment', 'recapture', 'capture', 'campaign', 'defence', 'surrender', 'rescue', 'conquest']
# cgBERT ['rented', 'licensed', 'contracted', 'occupied', 'reclaimed', 'took', 'sampled', 'appropriated', 'rent', 'obtained']
# cgBERT ['dense', 'thick', 'scarce', 'loose', 'thin', 'faint', 'soft', 'coarse', 'low', 'scattered']
# cgBERT ['rewards', 'opportunities', 'alternatives', 'outcomes', 'subsidies', 'activities', 'advantages', 'attractions', 'institutions', 'interventions']
# cgBERT ['instrument', 'object', 'axe', 'equipment', 'expression', 'item', 'tool', 'attribute', 'article', 'apparatus']
# cgBERT ['encourage', 'oppose', 'propose', 'support', 'associate', 'embrace', 'outlaw', 'employ', 'offer', 'affiliate']
# cgBERT ['amalgamated', 'integrated', 'linked', 'folded', 'combined', 'consolidated', 'changed', 'mixed', 'joined', 'developed']
# cgBERT ['netting', 'totaling', 'earning', 'costing', 'scoring', 'billing', 'purchasing', 'averaging', 'securing', 'investing']
# cgBERT ['subdivided', 'differentiated', 'categorized', 'graded', 'grouped', 'regarded', 'described', 'divided', 'categories', 'listed']
# cgBERT ['permit', 'accommodate', 'coordinate', 'ensure', 'achieve', 'ease', 'prompt', 'confirm', 'secure', 'schedule']
# cgBERT ['comprise', 'compose', 'are', 'form', 'represent', 'encompass', 'commence', 'occupy', 'denote', 'provide']
# cgBERT ['nose', 'muzzle', 'beak', 'noses', 'skull', 'tail', 'tails', 'forehead', 'nostrils', 'hood']
# cgBERT ['end', 'part', 'edge', 'arm', 'limit', 'angle', 'tip', 'boundary', 'side', 'point']
# cgBERT ['strive', 'aim', 'afford', 'as', 'endeavor', 'claim', 'undertake', 'attempt', 'pose', 'endeavour']
# cgBERT ['advanced', 'complex', 'complicated', 'specialized', 'elaborate', 'refined', 'rigorous', 'precise', 'modern', 'specialist']
# cgBERT ['encompassed', 'embraced', 'wiped', 'started', 'merged', 'leapt', 'reached', 'covered', 'stretched', 'crossed']
# cgBERT ['evade', 'escape', 'avoid', 'el', 'dodge', 'flee', 'eva', 'ignore', 'satisfy', 'escaped']
# cgBERT ['comprises', 'constitutes', 'incorporates', 'occupies', 'surrounds', 'addresses', 'contains', 'covers', 'is', 'spans']
# cgBERT ['includes', 'consists', 'encompasses', 'denotes', 'occupies', 'contains', 'employs', 'involves', 'provides', 'constitutes']
# cgBERT ['connects', 'coordinates', 'bonds', 'joins', 'ties', 'maps', 'holds', 'belongs', 'commits', 'attracts']
# cgBERT ['designated', 'listed', 'engraved', 'incorporated', 'enlisted', 'bestowed', 'assigned', 'incurred', 'denoted', 'honored']
# cgBERT ['confirms', 'agrees', 'insists', 'maintains', 'asserts', 'states', 'accepts', 'acknowledges', 'declares', 'announces']
# cgBERT ['anticipated', 'depicted', 'imagined', 'inhabited', 'dreamed', 'conceived', 'contemplated', 'projected', 'intended', 'expected']
# cgBERT ['irregular', 'eccentric', 'unusual', 'elusive', 'intermittent', 'unpredictable', 'uncertain', 'unconventional', 'unreliable', 'unstable']
# cgBERT ['affecting', 'changing', 'modifying', 'disturbing', 'improving', 'increasing', 'manipulating', 'violating', 'shifting', 'enhancing']
# cgBERT ['approved', 'ratified', 'accepted', 'established', 'agreed', 'passed', 'enacted', 'taken', 'endorsed', 'issued']
# cgBERT ['conserve', 'maintain', 'supply', 'exercise', 'store', 'update', 'reserve', 'keep', 'provide', 'feed']
# cgBERT ['likely', 'susceptible', 'frequent', 'resistant', 'liable', 'costly', 'robust', 'hazard', 'common', 'unlikely']
# cgBERT ['different', 'unusual', 'unconventional', 'particular', 'bizarre', 'eclectic', 'musical', 'strange', 'erratic', 'informal']
# cgBERT ['achieve', 'fulfill', 'implement', 'realize', 'attain', 'pursue', 'serve', 'obtain', 'perform', 'satisfy']
# cgBERT ['adequate', 'irresistible', 'exemplary', 'actual', 'benevolent', 'e', 'extraordinary', 'inclusive', 'immense', 'abundant']
# cgBERT ['famed', 'famous', 'infamous', 'ruthless', 'treacherous', 'reputed', 'outlawed', 'legendary', 'vicious', 'titular']
# cgBERT ['fight', 'conflict', 'contest', 'argument', 'battle', 'settlement', 'struggle', 'claim', 'feud', 'controversy']
# cgBERT ['avoid', 'escape', 'dodge', 'flee', 'pursue', 'avoided', 'resist', 'avoiding', 'avoids', 'escaped']
# cgBERT ['part', 'parish', 'town', 'settlement', 'village', 'portion', 'locality', 'chapel', 'borough', 'community']
# cgBERT ['anti', 'inner', 'actual', 'original', 'extra', 'extended', 'parallel', 'inter', 'expanded', 'early']
# cgBERT ['compatible', 'useful', 'convenient', 'fitting', 'appropriate', 'favourable', 'popular', 'pleasant', 'sufficient', 'attractive']
# cgBERT ['dying', 'sick', 'ill', 'elderly', 'injured', 'ai', 'growing', 'aged', 'old', 'struggling']
# cgBERT ['restrictions', 'barriers', 'difficulties', 'hurdles', 'challenges', 'opportunities', 'opposition', 'objectives', 'opponents', 'avenues']
# cgBERT ['migrated', 'immigrated', 'relocated', 'moved', 'escaped', 'proceeded', 'exported', 'fled', 'removed', 'and']
# cgBERT ['vital', 'basic', 'essential', 'profound', 'foundation', 'major', 'core', 'general', 'global', 'primal']
# cgBERT ['repair', 'rebuild', 'revive', 'improve', 'remake', 'recover', 'destroy', 'return', 'conserve', 'regain']
# cgBERT ['youth', 'young', 'teenage', 'youthful', 'junior', 'adolescent', 'trainee', 'criminal', 'cadet', 'child']
# cgBERT ['viewpoint', 'vantage', 'view', 'trajectory', 'position', 'angle', 'premise', 'projection', 'chronology', 'timeline']
# cgBERT ['reorganized', 'constituted', 'reunited', 'reformed', 'restored', 'gathered', 'reinstated', 'formed', 'assembled', 'founded']
# cgBERT ['derivatives', 'headwaters', 'basins', 'subsidiaries', 'sources', 'drains', 'rivers', 'satellites', 'predecessors', 'components']
# cgBERT ['vital', 'key', 'critical', 'essential', 'pivotal', 'decisive', 'important', 'helpful', 'necessary', 'fundamental']
# cgBERT ['written', 'created', 'constructed', 'recorded', 'published', 'formulated', 'formed', 'constituted', 'scored', 'made']
# cgBERT ['elaborate', 'extravagant', 'rich', 'expensive', 'extensive', 'large', 'heavy', 'costly', 'lush', 'massive']
# cgBERT ['breakup', 'termination', 'dissolution', 'death', 'downfall', 'formation', 'resignation', 'fate', 'collapse', 'fragmentation']
# cgBERT ['promised', 'swore', 'sworn', 'decreed', 'said', 'pledged', 'decided', 'wished', 'promising', 'guaranteed']
# cgBERT ['were', 'comprised', 'shaped', 'represented', 'became', 'like', 'featured', 'faced', 'formed', 'appeared']
# cgBERT ['safeguard', 'promote', 'flourish', 'create', 'strengthen', 'stimulate', 'revive', 'protect', 'maintain', 'harness']
# cgBERT ['offenses', 'crimes', 'violations', 'offences', 'acts', 'things', 'charges', 'actions', 'sins', 'abuses']
# cgBERT ['facilitate', 'support', 'encompass', 'relocate', 'harbor', 'permit', 'conceal', 'berth', 'shelter', 'contain']
# cgBERT ['voted', 'chose', 'campaigned', 'decided', 'preferred', 'voting', 'accounted', 'volunteered', 'favoured', 'participated']
# cgBERT ['rivalry', 'hostility', 'relationship', 'friendship', 'sentiment', 'disdain', 'hatred', 'aggression', 'interaction', 'conflict']
# cgBERT ['singer', 'frontman', 'soprano', 'novelist', 'drummer', 'rapper', 'performer', 'narrator', 'protagonist', 'bassist']
# cgBERT ['fake', 'produce', 'break', 'achieve', 'verify', 'secure', 'generate', 'copy', 'sign', 'create']
# cgBERT ['thorough', 'large', 'tremendous', 'gigantic', 'great', 'rich', 'considerable', 'wide', 'immense', 'broad']
# cgBERT ['support', 'material', 'proof', 'activity', 'trace', 'witness', 'information', 'experience', 'testimony', 'record']
# cgBERT ['both', 'unusually', 'several', 'extraordinary', 'large', 'very', 'notable', 'exceptionally', 'unusual', 'numerous']
# cgBERT ['opaque', 'clear', 'yellowish', 'clearer', 'yellow', 'white', 'invisible', 'tinted', 'visible', 'glass']
# cgBERT ['dead', 'widowed', 'departed', 'died', 'living', 'committed', 'dying', 'retired', 'fallen', 'childless']
# 100
# cgBERT ['advises', 'encourages', 'tells', 'charms', 'trails', 'invites', 'leads', 'orders', 'commands', 'influences']
# cgBERT ['completing', 'trying', 'making', 'appearing', 'achieving', 'initiating', 'approaching', 'failing', 'covering', 'executing']
# cgBERT ['yellow', 'reddish', 'yellowish', 'bronze', 'blond', 'horticultural', 'brown', 'metallic', 'red', 'floral']
# cgBERT ['resurgence', 'rebirth', 'renaissance', 'reunion', 'restoration', 'return', 'recovery', 'resort', 'reissue', 'salvage']
# cgBERT ['western', 'west', 'northwestern', 'central', 'french', 'westward', 'northwest', 'the', 'modern', 'northern']
# cgBERT ['pseudonym', 'nickname', 'name', 'surname', 'poet', 'brazilian', 'poem', 'writer', 'rapper', 'legend']
# cgBERT ['noted', 'remarked', 'described', 'claimed', 'said', 'confirmed', 'recorded', 'predicted', 'wrote', 'stated']
# cgBERT ['worked', 'partnered', 'teamed', 'participated', 'commissioned', 'authored', 'assisted', 'merged', 'accompanied', 'appeared']
# cgBERT ['district', 'division', 'arrondissement', 'region', 'municipality', 'commune', 'direction', 'diocese', 'town', 'ministry']
# cgBERT ['singer', 'practitioner', 'vocalist', 'soloist', 'presenter', 'player', 'specialist', 'participant', 'musician', 'producer']
# cgBERT ['excitement', 'passion', 'imagination', 'energy', 'activity', 'ambition', 'motivation', 'emotion', 'encouragement', 'fire']
# cgBERT ['firms', 'they', 'people', 'businesses', 'employers', 'cities', 'we', 'corporations', 'systems', 'manufacturers']
# cgBERT ['named', 'directed', 'entitled', 'labeled', 'headed', ',', 'called', 'designated', 'dubbed', 'composed']
# cgBERT ['extended', 'elliptical', 'altered', 'angled', 'oversized', 'long', 'erect', 'arched', 'oval', 'eccentric']
# cgBERT ['prominent', 'prestigious', 'significant', 'leadership', 'junior', 'powerful', 'central', 'major', 'chief', 'command']
# cgBERT ['back', 'player', 'cornerback', 'midfielder', 'fullback', 'hitter', 'winger', 'footballer', 'guard', 'keeper']
# cgBERT ['aspects', 'phenomena', 'events', 'parts', 'beliefs', 'portions', 'studies', 'measurements', 'appearances', 'knowledge']
# cgBERT ['district', 'division', 'nationale', 'region', 'arrondissement', 'section', 'commune', 'direction', 'diocese', 'sector']
# cgBERT ['negative', 'racist', 'controversial', 'harsh', 'vulgar', 'hostile', 'humorous', 'racial', 'positive', 'generic']
# cgBERT ['pause', 'hold', 'tour', 'recess', 'rotation', 'resume', 'contract', 'suspension', 'retirement', 'rehearsals']
# cgBERT ['implies', 'signifies', 'comprises', 'means', 'is', 'indicates', 'incorporates', 'describes', 'involves', 'depicts']
# cgBERT ['talent', 'capacity', 'flair', 'ability', 'variety', 'possibility', 'opportunity', 'caliber', 'spirit', 'role']
# cgBERT ['rule', 'campaign', 'time', 'throne', 'serve', 'tenure', 'period', 'realm', 'drive', 'service']
# cgBERT ['inhabitants', 'members', 'settlers', 'speakers', 'individuals', 'people', 'persons', 'homes', 'locations', 'civilians']
# cgBERT ['district', 'division', 'region', 'governorate', 'municipality', 'department', 'city', 'county', 'town', 'river']
# cgBERT ['encounters', 'visits', 'enters', 'abstracts', 'uses', 'approaches', 'hits', 'attacks', 'selects', 'opens']
# cgBERT ['less', 'more', 'smaller', 'greater', '<', 'lesser', 'farther', 'wilder', 'richer', 'weaker']
# cgBERT ['stayed', 'retained', 'continued', 'resided', 'appeared', 'persisted', 'lingered', 'returned', 'stood', 'existed']
# cgBERT ['maintained', 'kept', 'remained', 'continued', 'held', 'upheld', 'conserved', 'shared', 'resumed', 'defended']
# cgBERT ['historically', 'typically', 'usually', 'generally', 'commonly', 'often', 'originally', 'also', 'culturally', 'predominantly']
# cgBERT ['brought', 'imported', 'reintroduced', 'used', 'added', 'established', 'carried', 'present', 'provided', 'sold']
# cgBERT ['spores', 'varieties', 'bacteria', 'versions', 'generations', 'variants', 'cells', 'mutations', 'types', 'cultures']
# cgBERT ['touched', 'rocked', 'ravaged', 'fractured', 'threatened', 'hit', 'sustained', 'formed', 'visited', 'reached']
# cgBERT ['created', 'made', 'shaped', 'born', 'joined', 'founded', 'reformed', 'composed', 'obtained', 'comprised']
# cgBERT ['found', 'detected', 'published', 'observed', 'determined', 'located', 'named', 'announced', 'rediscovered', 'founded']
# cgBERT ['derive', 'gain', 'gather', 'attain', 'source', 'achieve', 'acquire', 'generate', 'get', 'derives']
# cgBERT ['broke', 'parted', 'married', 'separated', 'got', 'divided', 'reunited', 'cut', 'released', 'went']
# cgBERT ['period', 'department', 'area', 'division', 'place', 'decade', 'company', 'country', 'group', 'county']
# cgBERT ['persuaded', 'taught', 'told', 'motivated', 'inspired', 'led', 'influenced', 'fooled', 'helped', 'showed']
# cgBERT ['eventually', 'completely', 'violently', 'later', 'then', 'mostly', 'gradually', 'fully', 'finally', 'subsequently']
# cgBERT ['difficult', 'complicated', 'colourful', 'scrub', 'tight', 'straightforward', 'crucial', 'problematic', 'contentious', 'simple']
# cgBERT ['peeling', 'smoothing', 'hacking', 'slicing', 'hammering', 'cleaning', 'sampling', 'wiping', 'sliding', 'churning']
# cgBERT ['capital', 'offices', 'center', 'centers', 'chief', 'leaders', 'seats', 'capitals', 'hq', 'settlements']
# cgBERT ['thought', 'said', 'considered', 'known', 'reported', 'held', 'expected', 'understood', 'supposed', 'likely']
# cgBERT ['former', 'professional', 'disbanded', 'deceased', 'graduated', 'veteran', 'ex', 'experienced', 'recovered', 'active']
# cgBERT ['pine', 'cypress', 'fir', 'redwood', 'cedar', 'forested', 'forest', 'the', 'spruce', 'tree']
# cgBERT ['worked', 'assembled', 'excavated', 'rebuilt', 'formed', 'eroded', 'carved', 'produced', 'bored', 'manufactured']
# cgBERT ['title', 'collection', 'comics', 'miniseries', 'group', 'books', 'family', 'trilogy', 'comic', 'original']
# cgBERT ['reported', 'back', 'continued', 'turned', 'sent', 'sailed', 'referred', 'went', 'called', 'came']
# cgBERT ['idea', 'character', 'notion', 'system', 'theory', 'possibility', 'complex', 'term', 'phenomenon', 'hypothesis']
# cgBERT ['fledged', 'proper', 'capable', 'functional', 'mature', 'chartered', 'real', 'mainstream', 'functioning', 'true']
# cgBERT ['systematic', 'prescribed', 'disciplined', 'targeted', 'planned', 'scripted', 'scheduled', 'constructed', 'standardized', 'short']
# cgBERT ['arise', 'arrive', 'occur', 'begin', 'intercept', 'converge', 'initiate', 'exist', 'source', 'start']
# cgBERT ['desired', 'attempted', 'advocated', 'pursued', 'aimed', 'seeks', 'targeted', 'seeking', 'noted', 'began']
# cgBERT ['visuals', 'shots', 'photography', 'filming', 'imagery', 'filmmaking', 'cameras', 'scenes', 'sequences', 'footage']
# cgBERT ['important', 'crucial', 'necessary', 'vital', 'helpful', 'fundamental', 'integral', 'useful', 'used', 'required']
# cgBERT ['useful', 'valid', 'compelling', 'convincing', 'helpful', 'plausible', 'reassuring', 'comforting', 'practical', 'timely']
# cgBERT ['phenomena', 'events', 'instances', 'experiences', 'incidents', 'activities', 'observations', 'formations', 'situations', 'encounters']
# cgBERT ['criterion', 'conception', 'description', 'notion', 'method', 'design', 'statement', 'criteria', 'designation', 'interpretation']
# cgBERT ['usually', 'normally', 'roughly', 'broadly', 'typically', 'approximately', 'currently', 'often', 'initially', 'commonly']
# cgBERT ['subdivided', 'split', 'given', 'broken', 'separated', 'torn', 'placed', 'sub', 'sliced', 'shown']
# cgBERT ['located', 'headquartered', 'found', 'centered', 'living', 'born', 'residing', 'resident', 'from', 'released']
# cgBERT ['last', 'second', 'first', 'third', 'preliminary', 'ultimate', 'fourth', 'initial', 'current', 'main']
# cgBERT ['discovered', 'spotted', 'recorded', 'found', 'demonstrated', 'sighted', 'caught', 'noticed', 'observed', 'confirmed']
# cgBERT ['oppression', 'manipulation', 'suppression', 'harvesting', 'infringement', 'extraction', 'repression', 'abuse', 'use', 'occupation']
# cgBERT ['village', 'town', 'community', 'commune', 'city', 'hamlet', 'borough', 'parish', 'township', 'member']
# cgBERT ['accepted', 'collected', 'won', 'served', 'obtained', 'selected', 'took', 'placed', 'conducted', 'gained']
# cgBERT ['fades', 'collapses', 'sinks', 'separates', 'forms', 'drains', 'dies', 'loses', 'states', 'flees']
# cgBERT ['free', 'orderly', 'fair', 'peaceful', 'international', 'open', 'uniform', 'smooth', 'liberal', 'equal']
# cgBERT ['encounter', 'impact', 'exchange', 'mixing', 'contact', 'combination', 'association', 'incident', 'influence', 'appearance']
# cgBERT ['lake', 'dam', 'pond', 'pool', 'catchment', 'barrage', 'facility', 'tank', 'source', 'field']
# cgBERT ['declared', 'advertised', 'informed', 'stated', 'proclaimed', 'unveiled', 'ordered', 'revealed', 'explained', 'said']
# cgBERT ['made', 'installed', 'the', 'commissioned', 'named', 'elected', 'confirmed', 'established', 'awarded', 'acclaimed']
# cgBERT ['combining', 'uniting', 'linking', 'blending', 'joining', 'grouping', 'signing', 'unification', 'forming', 'amalgamation']
# cgBERT ['observed', 'noted', 'identified', 'evidenced', 'outlined', 'reported', 'advised', 'implied', 'suggested', 'showed']
# cgBERT ['condemned', 'threatened', 'attacked', 'controversial', 'banned', 'blamed', 'persecuted', 'questioned', 'investigated', 'proposed']
# cgBERT ['solely', 'entirely', 'only', 'strictly', 'primarily', 'specifically', 'purely', 'independently', 'universally', 'mainly']
# cgBERT ['rediscovered', 'found', 'uncovered', 'explored', 'founded', 'located', 'revealed', 'composed', 'detected', 'noticed']
# cgBERT ['bought', 'acquired', 'obtained', 'captured', 'owned', 'patented', 'claimed', 'sold', 'seized', 'chartered']
# cgBERT ['writer', 'author', 'cartoonist', 'narrator', 'publisher', 'protagonist', 'fiction', 'landlord', 'entrepreneur', 'fictional']
# cgBERT ['required', 'ob', 'mandated', 'forced', 'compelled', 'expected', 'ordered', 'allowed', 'exempt', 'disposed']
# cgBERT ['procedure', 'principle', 'scheme', 'method', 'process', 'practice', 'treatment', 'strategy', 'concept', 'methodology']
# cgBERT ['entities', 'associations', 'outfits', 'groups', 'structures', 'corporations', 'institutions', 'operations', 'centers', 'offices']
# cgBERT ['experienced', 'witnessed', 'lost', 'saw', 'had', 'endured', 'gained', 'sustained', 'scored', 'claimed']
# cgBERT ['modern', 'western', 'current', 'broader', 'australian', 'metropolitan', 'recent', 'southwestern', 'indigenous', 'postwar']
# cgBERT ['widely', 'usually', 'commonly', 'often', 'typically', 'largely', 'sometimes', 'broadly', 'normally', 'traditionally']
# cgBERT ['rest', 'duration', 'portion', 'majority', 'surplus', 'subsequent', 'termination', 'latter', 'disposition', 'bulk']
# cgBERT ['located', 'positioned', 'centred', 'precisely', 'constructed', 'found', 'perched', 'about', 'approximately', 'based']
# cgBERT ['concept', 'paradigm', 'device', 'plot', 'formula', 'metaphor', 'technique', 'narrative', 'scheme', 'storyline']
# cgBERT ['notable', 'leading', 'prevalent', 'common', 'popular', 'desirable', 'famous', 'significant', 'predominant', 'distinguished']
# cgBERT ['is', 'totals', 'reaches', 'estimates', 'equals', 'was', 'comprises', 'amounts', 'encompasses', 'numbers']
# cgBERT ['uncertain', 'unsure', 'unclear', 'doubtful', 'debating', 'unknown', 'deciding', 'divided', 'uncertainty', 'okay']
# cgBERT ['marketing', 'promoting', 'selling', 'announcing', 'targeting', 'expanding', 'ordering', 'broadcasting', 'offering', 'emphasizing']
# cgBERT ['usually', 'commonly', 'broadly', 'typically', 'often', 'widely', 'roughly', 'largely', 'normally', 'mostly']
# cgBERT ['forms', 'hits', 'lashes', 'reaches', 'impacts', 'attacks', 'battles', 'damages', 'blows', 'rocks']
# cgBERT ['formed', 'created', 'generated', 'made', 'caused', 'achieved', 'released', 'left', 'fired', 'forged']
# cgBERT ['measured', 'discovered', 'sensed', 'observed', 'spotted', 'found', 'registered', 'noticed', 'recorded', 'inspected']
# cgBERT ['granted', 'rejected', 'refused', 'barred', 'blocked', 'dismissed', 'discontinued', 'forbidden', 'excluded', 'suppressed']
# cgBERT ['produced', 'constructed', 'made', 'conceived', 'pronounced', 'practised', 'formed', 'synthesized', 'regulated', 'patented']
# cgBERT ['establish', 'provide', 'build', 'make', 'become', 'form', 'develop', 'present', 'produce', 'complete']
# 200
# cgBERT ['liquid', 'water', 'material', 'vapor', 'solvent', 'gas', 'medium', 'stream', 'flow', 'solid']
# cgBERT ['seen', 'reported', 'witnessed', 'recorded', 'identified', 'exhibited', 'caught', 'evidenced', 'operated', 'found']
# cgBERT ['conveyed', 'appeared', 'implied', 'suggested', 'revealed', 'emerged', 'displayed', 'evidenced', 'hinted', 'showed']
# cgBERT ['book', 'story', 'thriller', 'tale', 'fiction', 'series', 'paperback', 'work', 'mystery', 'crime']
# cgBERT ['certain', 'different', 'miscellaneous', 'common', 'some', 'the', 'several', 'other', 'seeking', 'dubious']
# cgBERT ['land', 'region', 'area', 'space', 'portion', 'tract', 'sphere', 'mound', 'remainder', 'wilderness']
# cgBERT ['never', 'not', 'usually', 'seldom', 'barely', 'occasionally', 'hardly', 'sometimes', 'frequently', 'sparsely']
# cgBERT ['difficult', 'severe', 'unpleasant', 'problematic', 'unfortunate', 'serious', 'violent', 'deadly', 'painful', 'unacceptable']
# cgBERT ['located', 'stationed', 'based', 'launched', 'anchored', 'centered', 'situated', ',', 'nationwide', 'concentrated']
# cgBERT ['force', 'strength', 'strong', 'degree', 'level', 'storm', 'high', 'power', 'season', 'scale']
# cgBERT ['presently', 'similarly', 'previously', 'additionally', 'typically', 'subsequently', 'generally', 'also', 'briefly', 'thus']
# cgBERT ['distinct', 'specific', 'memorable', 'distinctive', 'single', 'special', 'different', 'singular', 'custom', 'characteristic']
# cgBERT ['host', 'contestant', 'personality', 'participant', 'judge', 'moderator', 'commentator', 'presenter', 'guest', 'speaker']
# cgBERT ['occurrence', 'accessibility', 'existence', 'abundance', 'acquisition', 'absence', 'supply', 'appearance', 'eligibility', 'application']
# cgBERT ['enlisted', 'engaged', 'began', 'registered', 'embarked', 'boarded', 'entered', 'interned', 'initiated', 'commenced']
# cgBERT ['prominent', 'premier', 'eminent', 'important', 'pioneering', 'renowned', 'major', 'foremost', 'famous', 'influential']
# cgBERT ['settlement', 'area', 'subdivision', 'locality', 'village', 'location', 'destination', 'town', 'hamlet', 'place']
# cgBERT ['topic', 'motif', 'subject', 'feature', 'metaphor', 'concept', 'genre', 'issue', 'element', 'problem']
# cgBERT ['younger', 'last', 'former', 'heavier', 'remainder', 'remaining', 'youngest', 'other', 'neither', 'rear']
# cgBERT ['large', 'notable', 'major', 'sizable', 'small', 'substantial', 'considerable', 'portion', 'smaller', 'comparable']
# cgBERT ['tertiary', 'secondary', 'main', 'original', 'core', 'initial', 'first', 'predominant', 'sole', 'central']
# cgBERT ['property', 'plantation', 'house', 'farm', 'seat', 'domain', 'station', 'mansion', 'land', 'enterprise']
# cgBERT ['reference', 'science', 'reform', 'information', 'radio', 'r', 'review', 'study', 'work', 'development']
# cgBERT ['current', 'past', 'retired', 'previous', 'local', 'senior', 'defunct', 'recent', 'head', 'male']
# cgBERT ['aided', 'supported', 'helped', 'accompanied', 'provided', 'joined', 'served', 'augmented', 'attended', 'participated']
# cgBERT ['regularly', 'routinely', 'commonly', 'widely', 'readily', 'often', 'generally', 'heavily', 'typically', 'continually']
# cgBERT ['compartments', 'containers', 'areas', 'chambers', 'slots', 'sockets', 'tanks', 'pockets', 'spaces', 'sections']
# cgBERT ['terrible', 'exceptional', 'unacceptable', 'tragic', 'unpleasant', 'unexpected', 'disastrous', 'hideous', 'unhappy', 'extraordinary']
# cgBERT ['converting', 'rendering', 'reducing', 'encoding', 'turning', 'mapping', 'expressing', 'writing', 'compiling', 'copying']
# cgBERT ['foe', 'ally', 'partner', 'traitor', 'character', 'valet', 'negative', 'nemesis', 'leader', 'manager']
# cgBERT ['specialty', 'field', 'domain', 'division', 'profession', 'curriculum', 'genre', 'technique', 'department', 'subject']
# cgBERT ['elaborate', 'expansive', 'large', 'excessive', 'substantial', 'widespread', 'ample', 'enormous', 'intensive', 'abundant']
# cgBERT ['biggest', 'smallest', 'giant', 'major', 'longest', 'tallest', 'eldest', 'smaller', 'greatest', 'oldest']
# cgBERT ['portions', 'parts', 'segments', 'regions', 'tracts', 'areas', 'reaches', 'stretches', 'passages', 'divisions']
# cgBERT ['great', 'remarkable', 'formidable', 'magnificent', 'splendid', 'superb', 'powerful', 'brilliant', 'monumental', 'terrific']
# cgBERT ['comprised', 'played', 'sought', 'coveted', 'disputed', 'competed', 'produced', 'anticipated', 'obtained', 'held']
# cgBERT ['remnants', 'pieces', 'shards', 'survivors', 'bits', 'debris', 'remains', 'chunks', 'components', 'parts']
# cgBERT ['acquired', 'conquered', 'invaded', 'administered', 'submitted', 'integrated', 'incorporated', 'donated', 'adopted', 'ceded']
# cgBERT ['mirrored', 'mirror', 'revealed', 'echoed', 'addressed', 'expressed', 'yielded', 'showed', 'mirrors', 'did']
# cgBERT ['obtained', 'acquired', 'attained', 'regained', 'achieved', 'retained', 'secured', 'sought', 'became', 'got']
# cgBERT ['proprietor', 'businessman', 'founder', 'activist', 'author', 'investor', 'pioneer', 'philanthropist', 'inventor', 'administrator']
# cgBERT ['swallowed', 'enveloped', 'integrated', 'acquired', 'adopted', 'accepted', 'engulfed', 'incorporated', 'intercepted', 'merged']
# cgBERT ['several', 'numerous', 'many', 'two', 'single', 'different', 'consecutive', 'separate', 'simultaneous', 'various']
# cgBERT ['appeared', 'premiered', 'ran', 'screened', 'opened', 'served', 'concluded', 'broadcast', 'operated', 'released']
# cgBERT ['principles', 'law', 'beliefs', 'laws', 'norms', 'traditions', 'practices', 'customs', 'doctrines', 'practice']
# cgBERT ['recalls', 'echoes', 'suggests', 'follows', 'features', 'depicts', 'reflects', 'parallels', 'mentions', 'is']
# cgBERT ['label', 'mark', 'name', 'banner', 'term', 'team', 'trademark', 'sponsor', 'group', 'logo']
# cgBERT ['attacked', 'approached', 'harassed', 'ambushed', 'abducted', 'overwhelmed', 'violated', 'intercepted', 'injured', 'beaten']
# cgBERT ['declined', 'rejected', 'insisted', 'objected', 'protested', 'accepted', 'resisted', 'replied', 'answered', 'demanded']
# cgBERT ['subsequently', 'firstly', 'first', 'largely', 'early', 'previously', 'ultimately', 'originally', 'immediately', 'mainly']
# cgBERT ['via', 'thus', 'particularly', 'whereby', 'see', 'therefore', 'palais', 'consequently', 'specially', 'namely']
# cgBERT ['tried', 'began', 'enacted', 'aimed', 'managed', 'sought', 'intended', 'addressed', 'succeeded', 'failed']
# cgBERT ['uninhabited', 'isolated', 'accessible', 'remote', 'secluded', 'unavailable', 'wilderness', 'untouched', 'impossible', 'unfamiliar']
# cgBERT ['peripheral', 'southwestern', 'other', 'satellite', 'adjoining', 'isolated', 'offshore', 'associated', 'southernmost', 'neighbouring']
# cgBERT ['founded', 'began', 'organized', 'initiated', 'erected', 'acquired', 'concluded', 'opened', 'maintained', 'created']
# cgBERT ['basic', 'similar', 'central', 'complementary', 'fundamental', 'common', 'distinct', 'different', 'base', 'center']
# cgBERT ['opposite', 'analogous', 'anterior', 'next', 'contiguous', 'attached', 'subsequent', 'additional', 'neighboring', 'annexed']
# cgBERT ['portion', 'part', 'section', 'subsidiary', 'constituent', 'variant', 'unit', 'subdivision', 'core', 'branch']
# cgBERT ['informs', 'says', 'reads', 'told', 'warns', 'shows', 'gets', 'takes', 'gives', 'convinces']
# cgBERT ['depictions', 'illustrations', 'forms', 'appearances', 'performances', 'examples', 'versions', 'projections', 'copies', 'drawings']
# cgBERT ['aspects', 'features', 'items', 'issues', 'principles', 'parts', 'areas', 'details', 'themes', 'articles']
# cgBERT ['released', 'printed', 'completed', 'written', 'launched', 'republished', 'produced', 'discovered', 'held', 'introduced']
# cgBERT ['believe', 'think', 'regard', 'want', 'maintain', 'know', 'keep', 'call', 'classify', 'disregard']
# cgBERT ['assisted', 'supported', 'helped', 'encouraged', 'led', 'facilitated', 'guided', 'inspired', 'enabled', 'organized']
# cgBERT ['allows', 'enables', 'prohibits', 'forces', 'encourages', 'grants', 'supports', 'proceeds', 'provisions', 'facilitates']
# cgBERT ['always', 'mostly', 'typically', 'commonly', 'often', 'sometimes', 'generally', 'probably', 'originally', 'normally']
# cgBERT ['counterattack', 'response', 'revenge', 'resentment', 'backlash', 'vengeance', 'reaction', 'hostility', 'confrontation', 'compensation']
# cgBERT ['involved', 'affiliated', 'attributed', 'related', 'identified', 'corresponding', 'experienced', 'concurrent', 'allied', 'inherent']
# cgBERT ['person', 'man', 'mortal', 'civilian', 'male', 'pedestrian', 'body', 'vampire', 'civil', 'criminal']
# cgBERT ['revolt', 'plot', 'revolution', 'conspiracy', 'mutiny', 'rebellion', 'dictatorship', 'overthrow', 'junta', 'crash']
# cgBERT ['founded', 'created', 'assembled', 'composed', 'started', 'developed', 'joined', 'began', 'established', 'begun']
# cgBERT ['intentionally', 'purposely', 'consciously', 'secretly', 'precisely', 'accidentally', 'forcibly', 'somehow', 'supposedly', 'subtly']
# cgBERT ['system', 'scheme', 'company', 'route', 'franchise', 'property', 'grid', 'record', 'line', 'land']
# cgBERT ['invading', 'comprising', 'in', 'filling', 'assuming', 'encompassing', 'adjoining', 'obtaining', 'throughout', 'taking']
# cgBERT ['significant', 'prominent', 'historic', 'famed', 'famous', 'major', 'remarkable', 'distinguished', 'large', 'renowned']
# cgBERT ['escape', 'mutiny', 'evacuation', 'escapes', 'revolt', 'theft', 'exodus', 'bust', 'retreat', 'release']
# cgBERT ['elements', 'components', 'materials', 'entries', 'constituents', 'additions', 'substances', 'chemicals', 'items', 'nutrients']
# cgBERT ['administering', 'spreading', 'supplying', 'promoting', 'issuing', 'circulating', 'releasing', 'providing', 'lending', 'selling']
# cgBERT ['devotees', 'followers', 'practitioners', 'converts', 'members', 'viewers', 'attendees', 'respondents', 'inhabitants', 'disciples']
# cgBERT ['chanting', 'dancing', 'performing', 'playing', 'screaming', 'together', 'crying', 'sang', 'sung', 'cheering']
# cgBERT ['descends', 'stems', 'differs', 'comes', 'arises', 'originates', 'yields', 'springs', 'distinguishes', 'declines']
# cgBERT ['owned', 'run', 'controlled', 'governed', 'conducted', 'led', 'served', 'administered', 'managed', 'founded']
# cgBERT ['played', 'represented', 'performed', 'depicted', 'voiced', 'introduced', 'presented', 'appeared', 'embodied', 'hosted']
# cgBERT ['created', 'designed', 'redeveloped', 'built', 'ported', 'derived', 'played', 'evolved', 'released', 'produced']
# cgBERT ['slopes', 'terraces', 'ridges', 'cliffs', 'grades', 'edges', 'defences', 'sides', 'declines', 'ramps']
# cgBERT ['called', 'named', 'rebranded', 'dubbed', 'styled', 'baptized', 'founded', 'nicknamed', 'changed', 'redesignated']
# cgBERT ['formed', 'established', 'begun', 'started', 'launched', 'discovered', 'created', 'born', 'located', 'began']
# cgBERT ['yearly', 'overall', 'local', 'daily', 'average', 'regional', 'absolute', 'biennial', 'seasonal', 'permanent']
# cgBERT ['extent', 'basis', 'framework', 'locus', 'concept', 'constitution', 'methodology', 'scale', 'breadth', 'purpose']
# cgBERT ['entitled', 'regarded', 'principally', 'commenced', 'baptised', 'deemed', 'characterised', 'constituted', 'designated', 'named']
# cgBERT ['inhabitants', 'speakers', 'dwellers', 'locals', 'members', 'citizens', 'settlers', 'owners', 'islanders', 'families']
# cgBERT ['ended', 'stayed', 'continued', 'stretched', 'persisted', 'waited', 'went', 'ran', 'lived', 'cried']
# cgBERT ['selected', 'chosen', 'picked', 'drafted', 'decided', 'revealed', 'screened', 'announced', 'created', 'specified']
# cgBERT ['theory', 'model', 'scenario', 'proposal', 'scheme', 'thesis', 'concept', 'doctrine', 'paradigm', 'geology']
# cgBERT ['gathered', 'co', 'collected', 'had', 'kidnapped', 'captured', 'found', 'released', 'were', 'recruited']
# cgBERT ['level', 'stage', 'deck', 'row', 'storey', 'balcony', 'truss', 'section', 'terrace', 'partition']
# cgBERT ['slowly', 'steadily', 'eventually', 'successively', 'progressively', 'largely', 'continuously', 'rapidly', 'mostly', 'then']
# cgBERT ['evolved', 'appeared', 'arose', 'developed', 'originated', 'erupted', 'began', 'expanded', 'occurred', 'escaped']
# cgBERT ['altitude', 'incidence', 'enrollment', 'upland', 'average', 'area', 'ascent', 'height', 'alpine', 'income']
# cgBERT ['involved', 'began', 'was', 'added', 'meant', 'continued', 'covered', 'consisted', 'required', 'started']
# 300
# cgBERT ['including', 'notwithstanding', 'ignoring', 'beyond', 'preventing', 'qualifying', 'minus', 'avoiding', 'overlooking', 'eliminating']
# cgBERT ['nonetheless', 'still', 'indeed', 'although', 'accordingly', 'therefore', 'however', 'notwithstanding', 'moreover', 'furthermore']
# cgBERT ['responsible', 'aimed', 'provided', 'participated', 'opted', 'amounted', 'contributed', 'stood', 'composed', 'arrived']
# cgBERT ['save', 'seal', 'conserve', 'survive', 'retain', 'keep', 'protect', 'destroy', 'sustain', 'ensure']
# cgBERT ['performing', 'employing', 'using', 'serving', 'executing', 'running', 'airing', 'conducting', 'ordering', 'flying']
# cgBERT ['addresses', 'lists', 'holds', 'displays', 'delivers', 'incorporates', 'includes', 'encompasses', 'portrays', 'describes']
# cgBERT ['biggest', 'largest', 'worst', 'highest', 'lowest', 'greatest', 'maximum', 'deepest', 'strongest', 'longest']
# cgBERT ['steadily', 'periodically', 'gradually', 'permanently', 'eventually', 'slowly', 'regularly', 'progressively', 'repeatedly', 'completely']
# cgBERT ['rolling', 'straightening', 'rough', 'rubbing', 'cleaning', 'grinding', 'soothing', 'covering', 'grazing', 'drying']
# cgBERT ['occupants', 'arrivals', 'residents', 'settlers', 'invaders', 'people', 'representatives', 'ancestors', 'peoples', 'youths']
# cgBERT ['recording', 'watching', 'filming', 'documenting', 'measuring', 'logging', 'protesting', 'showing', 'reviewing', 'monitoring']
# cgBERT ['additional', 'inaugural', 'original', 'first', 'subsequent', 'final', 'early', 'following', 'previous', 'incoming']
# cgBERT ['show', 'segment', 'series', 'host', 'personality', 'format', 'broadcast', 'portion', 'competition', 'title']
# cgBERT ['generally', 'often', 'popularly', 'typically', 'widely', 'colloquially', 'usually', 'professionally', 'also', 'frequently']
# cgBERT ['establishes', 'states', 'maintains', 'is', 'extends', 'concerns', 'recounts', 'declares', 'identifies', 'emerges']
# cgBERT ['incredibly', 'highly', 'intensely', 'overwhelmingly', 'immensely', 'severely', 'exceptionally', 'very', 'exceeding', 'ultra']
# cgBERT ['stop', 'avoid', 'deter', 'prohibit', 'save', 'interrupt', 'halt', 'protect', 'control', 'ensure']
# cgBERT ['sight', 'perception', 'eye', 'view', 'blind', 'blindness', 'seeing', 'image', 'mind', 'hearing']
# cgBERT ['several', 'numerous', 'different', 'differing', 'diverse', 'many', 'similar', 'certain', 'multiple', 'common']
# cgBERT ['person', 'actor', 'role', 'figure', 'player', 'protagonist', 'personality', 'hero', 'concept', 'individual']
# cgBERT ['arises', 'raises', 'begins', 'rose', 'forms', 'springs', 'originates', 'stands', 'lies', 'comes']
# cgBERT ['declared', 'said', 'announced', 'released', 'wrote', 'spoke', 'commented', 'noted', 'mentioned', 'specified']
# cgBERT ['purpose', 'objective', 'offense', 'emphasis', 'effort', 'understanding', 'object', 'aim', 'effect', 'attempt']
# cgBERT ['previous', 'historic', 'past', 'current', 'nominal', 'historical', 'latter', 'defunct', 'prior', 'earlier']
# cgBERT ['signal', 'determine', 'identify', 'confirm', 'mark', 'document', 'inform', 'designate', 'reveal', 'announce']
# cgBERT ['influenced', 'adapted', 'animated', 'based', 'informed', 'motivated', 'triggered', 'invented', 'prompted', 'caused']
# cgBERT ['students', 'pupils', 'boys', 'children', 'persons', 'players', 'fellows', 'men', 'sons', 'brothers']
# cgBERT ['government', 'rule', 'state', 'dictatorship', 'party', 'system', 'programme', 'ruler', 'republic', 'power']
# cgBERT ['instance', 'interpreter', 'application', 'environment', 'optimization', 'interpretation', 'algorithm', 'equivalent', 'example', 'infrastructure']
# cgBERT ['went', 'participated', 'travelled', 'commenced', 'replied', 'committed', 'attended', 'undertook', 'was', 'embarked']
# cgBERT ['tehsil', 'division', 'sector', 'locality', 'neighbourhood', 'component', 'branch', 'part', 'grouping', 'section']
# cgBERT ['called', 'titled', 'thought', 'deemed', 'respected', 'regarded', 'held', 'named', 'recorded', 'likely']
# cgBERT ['tip', 'cape', 'point', 'part', 'coastline', 'wedge', 'gulf', 'coast', 'corner', 'snout']
# cgBERT ['show', 'hide', 'disclose', 'conceal', 'reflect', 'change', 'display', 'betray', 'indicate', 'disguise']
# cgBERT ['ease', 'immunity', 'terror', 'certainty', 'probability', 'authority', 'silence', 'precision', 'indifference', 'violence']
# cgBERT [',', 'completely', 'well', 'all', 'properly', 'unsuccessfully', 'effectively', 'easily', 'carefully', 'physically']
# cgBERT ['landmark', 'famous', 'legendary', 'iconic', 'popular', 'seminal', 'epic', 'pioneering', 'historic', 'original']
# cgBERT ['standard', 'mass', 'classical', 'conventional', 'wider', 'orthodox', 'regular', 'legitimate', 'vernacular', 'traditional']
# cgBERT ['reliable', 'credible', 'valuable', 'worthy', 'stable', 'accurate', 'genuine', 'friendly', 'loyal', 'useful']
# cgBERT ['last', 'terminal', 'closing', 'first', 'second', 'concluding', 'remaining', 'third', 'ending', 'penultimate']
# cgBERT ['minor', 'small', 'significant', 'considerable', 'substantial', 'minimal', 'modest', 'major', 'short', 'subtle']
# cgBERT ['responds', 'refers', 'translates', 'reduces', 'connects', 'applies', 'links', 'ties', 'measures', 'scales']
# cgBERT ['and', 'cattle', 'stock', 'animal', 'sheep', 'animals', 'horse', 'poultry', 'property', 'or']
# cgBERT ['tract', 'time', 'range', 'group', 'position', 'sequence', 'interval', 'duration', 'region', 'spell']
# cgBERT ['distinctive', 'typical', 'decorative', 'trademark', 'feature', 'traditional', 'unique', 'colorful', 'features', 'signature']
# cgBERT ['unveiled', 'released', 'introduced', 'ordered', 'advertised', 'published', 'opened', 'inaugurated', 'established', 'approved']
# cgBERT ['comparatively', 'fairly', 'typically', 'generally', 'moderately', 'very', 'reasonably', 'rather', 'somewhat', 'extremely']
# cgBERT ['accessible', 'unavailable', 'impossible', 'invisible', 'uninhabited', 'unknown', 'accessibility', 'navigable', 'available', 'isolated']
# cgBERT ['centred', 'concentrated', 'based', 'keen', 'specialised', 'fixed', 'rounded', 'organised', 'recognised', 'restricted']
# cgBERT ['type', 'form', 'style', 'dialect', 'diversity', 'version', 'strain', 'corruption', 'range', 'grammar']
# cgBERT ['write', 'design', 'develop', 'produce', 'find', 'provide', 'make', 'present', 'include', 'capture']
# cgBERT ['sovereign', 'king', 'royalty', 'ruler', 'royalist', 'regent', 'viceroy', 'baronet', 'queen', 'premier']
# cgBERT ['arranged', 'developed', 'edited', 'applied', 'turned', 'adopted', 'elaborated', 'converted', 'engineered', 'inspired']
# cgBERT ['instantly', 'extremely', 'initially', 'quickly', 'unexpectedly', 'already', 'very', 'instant', 'easily', 'directly']
# cgBERT ['bordered', 'contracted', 'contested', 'formed', 'signed', 'traced', 'located', 'surrounded', 'considered', 'characterized']
# cgBERT ['sent', 'loaned', 'migrated', 'donated', 'returned', 'moved', 'relocated', 'switched', 'referred', 'removed']
# cgBERT ['kidnap', 'catch', 'trap', 'take', 'claim', 'arrest', 'secure', 'collect', 'land', 'free']
# cgBERT ['supplied', 'furnished', 'formed', 'composed', 'rendered', 'generated', 'contributed', 'performed', 'contracted', 'gave']
# cgBERT ['focuses', 'focus', 'centres', 'works', 'catalogue', 'mainly', 'emphasis', 'carries', 'specializes', 'nowadays']
# cgBERT ['prevent', 'ban', 'forbid', 'eliminate', 'suppress', 'restrict', 'regulate', 'require', 'cease', 'curb']
# cgBERT ['minimize', 'decrease', 'lower', 'save', 'preserve', 'alleviate', 'reflect', 'conserve', 'contain', 'bear']
# cgBERT ['comparatively', 'slightly', 'somewhat', 'significantly', 'tract', 'much', 'particularly', 'notably', 'predominantly', 'noticeably']
# cgBERT ['need', 'demand', 'undergo', 'include', 'involve', 'seek', 'employ', 'must', 'assume', 'provide']
# cgBERT ['clash', 'encounter', 'shootout', 'showdown', 'interaction', 'reconciliation', 'manifestation', 'coupling', 'collision', 'enclosure']
# cgBERT ['recently', 'briefly', 'initially', 'subsequently', 'already', 'earlier', 'formerly', 'also', 'similarly', 'historically']
# cgBERT ['infants', 'babies', 'prospects', 'births', 'young', 'casualties', 'infant', 'adolescents', 'children', 'teenagers']
# cgBERT ['encompassed', 'embraced', 'crossed', 'covered', 'wiped', 'conquered', 'encompasses', 'across', 'drained', 'lasted']
# cgBERT ['ultimate', 'supreme', 'lowest', 'utmost', 'top', 'maximum', 'greatest', 'paramount', 'best', 'only']
# cgBERT ['stem', 'originate', 'descend', 'gain', 'differ', 'generate', 'branch', 'arise', 'evolve', 'source']
# cgBERT ['siege', 'stormed', 'conquered', 'raided', 'invaded', 'attacked', 'captured', 'bombed', 'occupied', 'recaptured']
# cgBERT ['accepted', 'won', 'rewarded', 'given', 'garnered', 'collected', 'selected', 'obtained', 'funded', 'awarded']
# cgBERT ['plotted', 'planned', 'orchestrated', 'compromised', 'worked', 'negotiated', 'decided', 'fought', 'played', 'struggled']
# cgBERT ['threatening', 'imposing', 'terrifying', 'ominous', 'sinister', 'fearful', 'disturbing', 'intimidating', 'frightening', 'enraged']
# cgBERT ['moon', 'sphere', 'hemisphere', 'part', 'component', 'spacecraft', 'crater', 'target', 'twin', 'orbit']
# cgBERT ['commonly', 'frequently', 'usually', 'generally', 'traditionally', 'currently', 'annually', 'routinely', 'primarily', 'notably']
# cgBERT ['support', 'reason', 'proof', 'indication', 'information', 'influence', 'material', 'activity', 'opposition', 'industry']
# cgBERT ['lays', 'lay', 'is', 'stands', 'sits', 'stretches', 'rests', 'runs', 'rises', 'lands']
# cgBERT ['build', 'manufacture', 'erect', 'create', 'establish', 'comprise', 'relocate', 'commence', 'develop', 'provide']
# cgBERT ['changed', 'shifted', 'transferred', 'relocated', 'transported', 'displaced', 'placed', 'migrated', 'pushed', 'removed']
# cgBERT ['journey', 'voyage', 'depart', 'trip', 'move', 'visit', 'fly', 'migrate', 'flee', 'go']
# cgBERT ['generally', 'broadly', 'commonly', 'well', 'internationally', 'largely', 'best', 'worldwide', 'universally', 'frequently']
# cgBERT ['established', 'founded', 'created', 'began', 'started', 'formed', 'instituted', 'inaugurated', 'initiated', 'revived']
# cgBERT ['approximate', 'mimic', 'recall', 'reproduce', 'imitation', 'comprise', 'like', 'shape', 'include', 'copy']
# cgBERT ['given', 'killed', 'helped', 'decided', 'produced', 'started', 'forced', 'scored', 'thrown', 'marked']
# cgBERT ['major', 'large', 'substantial', 'critical', 'notable', 'key', 'meaningful', 'huge', 'considerable', 'historic']
# cgBERT ['form', 'have', 'contract', 'display', 'decline', 'establish', 'present', 'grow', 'show', 'become']
# cgBERT ['bought', 'acquired', 'sold', 'held', 'organized', 'purchased', 'inherited', 'operated', 'known', 'controlled']
# cgBERT ['exhibited', 'witnessed', 'showed', 'discovered', 'performed', 'constructed', 'conceived', 'observed', 'sustained', 'characterized']
# cgBERT ['disguise', 'hide', 'camouflage', 'mask', 'reveal', 'obscure', 'disguised', 'cloak', 'veil', 'covert']
# cgBERT ['forbid', 'taboo', 'prescription', 'ban', 'banning', 'limitation', 'suppression', 'boycott', 'restriction', 'defiance']
# cgBERT ['violent', 'dry', 'dull', 'troubled', 'dirty', 'dark', 'rough', 'rainy', 'torn', 'terrible']
# cgBERT ['determines', 'defines', 'determine', 'regulates', 'sets', 'provides', 'indicates', 'specifies', 'affects', 'creates']
# cgBERT ['summon', 'meet', 'call', 'gather', 'command', 'bring', 'assemble', 'invite', 'prompt', 'council']
# cgBERT ['findings', 'operations', 'studies', 'images', 'measurements', 'investigations', 'recordings', 'discoveries', 'errors', 'assignments']
# cgBERT ['buildings', 'blocks', 'complexes', 'structures', 'offices', 'centers', 'centres', 'floors', 'chains', 'flats']
# cgBERT ['slowly', 'progressively', 'eventually', 'successively', 'steadily', 'continuously', 'continually', 'rapidly', 'then', 'quickly']
# cgBERT ['skills', 'assistance', 'practices', 'firms', 'contracts', 'activities', 'duties', 'companies', 'talents', 'ways']
# cgBERT ['emitted', 'produced', 'dissipated', 'discharged', 'lost', 'leaked', 'raised', 'surrendered', 'created', 'freed']
# cgBERT ['appear', 'allow', 'arise', 'account', 'originate', 'reside', 'excel', 'include', 'operate', 'have']
# cgBERT ['wandering', 'stalking', 'roaming', 'patrolling', 'lurking', 'scouting', 'sneaking', 'walking', 'drifting', 'lingering']
# 400
# cgBERT ['differentiate', 'identify', 'contrast', 'separate', 'determine', 'recognize', 'differ', 'designate', 'mark', 'establish']
# cgBERT ['nas', 'fledgling', 'first', 'developing', 'newborn', 'former', 'earliest', 'founding', 'early', 'precursor']
# cgBERT ['covers', 'encompasses', 'adds', 'collects', 'remains', 'combines', 'involves', 'is', 'calls', 'totals']
# cgBERT ['border', 'frontier', 'interface', 'ground', 'difference', 'limit', 'relationship', 'distinction', 'margin', 'division']
# cgBERT ['built', 'intended', 'planned', 'redesigned', 'constructed', 'located', 'dedicated', 'developed', 'engineered', 'founded']
# cgBERT ['begun', 'started', 'organized', 'introduced', 'enacted', 'inaugurated', 'prompted', 'authored', 'originated', 'implemented']
# cgBERT ['location', 'scene', 'seat', 'source', 'subject', 'centre', 'home', 'center', 'place', 'point']
# cgBERT ['rolled', 'ran', 'raced', 'continued', 'headed', 'approached', 'fed', 'climbed', 'moved', 'turned']
# cgBERT ['generates', 'performs', 'makes', 'yields', 'creates', 'leaves', 'outputs', 'represents', 'supports', 'has']
# cgBERT ['important', 'early', 'edited', 'active', 'impressive', 'inspirational', 'innovative', 'educated', 'obscure', 'effective']
# cgBERT ['eccentric', 'regular', 'elliptical', 'elongated', 'elliptic', 'erratic', 'unusual', 'uneven', 'the', 'stony']
# cgBERT ['mythical', 'famed', 'mystical', 'fictional', 'titular', 'notorious', 'mythological', 'supposed', 'reputed', 'fictitious']
# cgBERT ['prevent', 'escape', 'evade', 'eliminate', 'assure', 'keep', 'ease', 'save', 'exclude', 'risk']
# cgBERT ['skirt', 'loop', 'traverse', 'avoid', 'pass', 'miss', 'hit', 'span', 'disregard', 'ignore']
# cgBERT ['creates', 'offers', 'presents', 'establishes', 'includes', 'supports', 'portrays', 'forms', 'comprises', 'performs']
# cgBERT ['sent', 'moved', 'relegated', 'switched', 'returned', 'separated', 'loaned', 'promoted', 'admitted', 'joined']
# cgBERT ['is', 'lays', 'runs', 'sits', 'stands', 'stretches', 'falls', 'rests', 'lay', 'rises']
# cgBERT ['concluded', 'culminated', 'occurred', 'succeeded', 'ensued', 'consisted', 'produced', 'yielded', 'terminated', 'ended']
# cgBERT ['depicts', 'reflects', 'delegates', 'hosts', 'serves', 'supports', 'portrays', 'indicates', 'involves', 'performs']
# cgBERT ['equivalent', 'currency', 'literal', 'nominal', 'rounded', 'coined', 'fixed', 'monetary', 'correlated', 'subject']
# cgBERT ['switched', 'lost', 'dumped', 'slipped', 'gave', 'abandoned', 'lowered', 'changed', 'left', 'released']
# cgBERT ['attributed', 'due', 'traced', 'related', 'linked', 'restricted', 'reduced', 'assigned', 'owing', 'equivalent']
# cgBERT ['colour', 'sheen', 'coloration', 'appearance', 'color', 'quality', 'qualities', 'colours', 'complexion', 'shade']
# cgBERT ['memorable', 'res', 'fitting', 'compelling', 'comforting', 'vocal', 'expressive', 'difficult', 'significant', 'volatile']
# cgBERT ['highlighted', 'rediscovered', 'lauded', 'curated', 'showcased', 'endorsed', 'praised', 'revered', 'headlined', 'explored']
# cgBERT ['standard', 'starting', 'guide', 'counter', 'control', 'test', 'bench', 'ground', 'base', 'common']
# cgBERT ['afterward', 'beforehand', 'northward', 'subsequently', 'afterwards', 'likewise', 'consequently', 'accordingly', 'nonetheless', 'concurrently']
# cgBERT ['starred', 'performed', 'acted', 'featured', 'participated', 'played', 'debuted', 'was', 'worked', 'spoke']
# cgBERT ['mostly', 'largely', 'mainly', 'predominantly', 'chiefly', 'typically', 'originally', 'essentially', 'generally', 'initially']
# cgBERT ['elected', 'installed', 'established', 'confirmed', 'introduced', 'awarded', 'announced', 'made', 'employed', 'created']
# cgBERT ['touches', 'focuses', 'speaks', 'takes', 'comments', 'reflects', 'draws', 'focus', 'comment', 'centers']
# cgBERT ['possible', 'probable', 'future', 'likely', 'prospective', 'mere', 'maximum', 'sustained', 'the', 'current']
# cgBERT ['allow', 'facilitate', 'offer', 'provide', 'afford', 'imply', 'improve', 'incorporate', 'organise', 'involve']
# cgBERT ['sponsored', 'sanctioned', 'supported', 'approved', 'backed', 'mandated', 'lauded', 'authorized', 'funded', 'favored']
# cgBERT ['naming', 'building', 'settling', 'beginning', 'launching', 'forming', 'creation', 'creating', 'starting', 'establishing']
# cgBERT ['originally', 'previously', 'immediately', 'earlier', 'generally', 'early', 'ultimately', 'also', 'subsequently', 'first']
# cgBERT ['rotational', 'dynamic', 'the', 'mechanical', 'total', 'longitudinal', 'ballistic', 'rhythmic', 'molecular', 'angular']
# cgBERT ['annoyance', 'complaint', 'amusement', 'agony', 'frustration', 'impatience', 'agitation', 'embarrassment', 'discomfort', 'tingling']
# cgBERT ['scandal', 'discussion', 'debate', 'publicity', 'criticism', 'protest', 'distinction', 'suspicion', 'scrutiny', 'notoriety']
# cgBERT ['recognized', 'indicated', 'recognised', 'established', 'experienced', 'uncovered', 'determined', 'assessed', 'emerged', 'located']
# cgBERT ['recent', 'newest', 'last', 'newer', 'fresh', 'sour', 'current', 'recently', 'nowadays', 'southern']
# cgBERT ['games', 'fixtures', 'competitions', 'events', 'ties', ',', 'meetings', 'contests', 'tournaments', 'finals']
# cgBERT ['negative', 'sinister', 'similar', 'menacing', 'hostile', 'strong', 'contrary', 'positive', 'strange', 'malicious']
# cgBERT ['putting', 'installing', 'performing', 'laying', 'building', 'removing', 'constructing', 'establishing', 'setting', 'positioning']
# cgBERT ['mated', 'engineered', 'matched', 'traded', 'blended', 'born', 'mixed', 'crossed', 'fed', 'grown']
# cgBERT ['chief', 'premier', 'paramount', 'principal', 'sole', 'chiefly', 'principle', 'primary', 'main', 'predominant']
# cgBERT ['secured', 'confirmed', 'resolved', 'notified', 'sanctioned', 'declared', 'endorsed', 'attained', 'stipulated', 'ceded']
# cgBERT ['blank', 'flat', 'white', 'uniform', 'smooth', 'continuous', 'dark', 'dry', 'perpetual', 'black']
# cgBERT ['wealthy', 'affluent', 'flourishing', 'thriving', 'desirable', 'lucrative', 'successful', 'rich', 'powerful', 'distinguished']
# cgBERT ['challenges', 'mysteries', 'clues', 'squares', 'constraints', 'problems', 'difficulties', 'bugs', 'characters', 'solutions']
# cgBERT ['layout', 'spread', 'tabloid', 'mural', 'biennial', 'visual', 'centennial', 'cameo', 'photo', 'silhouette']
# cgBERT ['observed', 'saw', 'demonstrated', 'experienced', 'noticed', 'learnt', 'encountered', 'reported', 'overheard', 'caught']
# cgBERT ['houses', 'spots', 'has', 'hosts', 'is', 'showcases', 'seats', 'includes', 'displays', 'contains']
# cgBERT ['largely', 'mainly', 'typically', 'chiefly', 'predominantly', 'mostly', 'solely', 'historically', 'prominently', 'generally']
# cgBERT ['lays', 'is', 'measures', 'lay', 'sits', 'stands', 'rests', 'runs', 'lands', 'curves']
# cgBERT ['outburst', 'explosion', 'outbreak', 'evacuation', 'episode', 'ascent', 'occurrence', 'excavation', 'arc', 'occupation']
# cgBERT ['seldom', 'frequently', 'never', 'commonly', 'occasionally', 'hardly', 'barely', 'typically', 'scarcely', 'sparsely']
# cgBERT ['dispatched', 'ordered', 'directed', 'told', 'commanded', 'appointed', 'mandated', 'informed', 'asked', 'entrusted']
# cgBERT ['cause', 'provide', 'participate', 'add', 'factor', 'help', 'lead', 'amount', 'react', 'rise']
# cgBERT ['graded', 'registered', 'verified', 'accredited', 'stamped', 'ranked', 'logged', 'recorded', 'ratified', 'platinum']
# cgBERT ['neighboring', 'nearby', 'unrelated', 'surrounding', 'entire', 'next', 'attached', 'additional', 'upcoming', 'associated']
# cgBERT ['compelled', 'caused', 'drove', 'took', 'required', 'demanded', 'convinced', 'allowed', 'induced', 'brought']
# cgBERT ['siege', 'stormed', 'fortified', 'threatened', 'encircled', 'bombed', 'raided', 'evacuated', 'invested', 'leased']
# cgBERT ['renewed', 'new', 'improved', 'enhanced', 'revived', 'strengthened', 'transformed', 'changed', 'healing', 'continued']
# cgBERT ['altered', 'included', 'modified', 'incorporated', 'appropriate', 'changed', 'used', 'updated', 'archived', 'shown']
# cgBERT ['translated', 'converted', 'adapted', 'licensed', 'localized', 'serialized', 'transferred', 'released', 'generalized', 'developed']
# cgBERT ['located', 'featured', 'exhibited', 'showcased', 'demonstrated', 'stored', 'viewed', 'shown', 'stocked', 'depicted']
# cgBERT ['finding', 'locating', 'detecting', 'naming', 'identifying', 'numbering', 'pioneering', 'constructing', 'measuring', 'publishing']
# cgBERT ['animals', 'strains', 'ones', 'trunks', 'beings', 'creatures', 'examples', 'males', 'fossils', 'recruits']
# cgBERT ['denote', 'indicate', 'represent', 'mean', 'recognize', 'designate', 'form', 'identify', 'label', 'rank']
# cgBERT ['nominees', 'recipients', 'winners', 'finalists', 'candidates', 'prizes', 'strikers', 'contenders', 'competitors', 'names']
# cgBERT ['located', 'positioned', 'lodged', 'comprised', 'constituted', 'erected', 'centred', 'modelled', 'placed', 'stationed']
# cgBERT ['form', 'title', 'variation', 'name', 'variant', 'word', 'portion', 'translation', 'copy', 'mix']
# cgBERT ['started', 'led', 'decided', 'forced', 'killed', 'involved', 'explained', 'had', 'triggered', 'connected']
# cgBERT ['collects', 'takes', 'receives', 'destroys', 'repairs', 'extracts', 'pulls', 'transfers', 'separates', 'performs']
# cgBERT ['objects', 'objectives', 'obstacles', 'bases', 'structures', 'prizes', 'vehicles', 'positions', 'locations', 'weapons']
# cgBERT ['mounted', 'placed', 'erected', 'exhibited', 'constructed', 'housed', 'built', 'commissioned', 'implemented', 'inaugurated']
# cgBERT ['typically', 'historically', 'usually', 'generally', 'culturally', 'often', 'normally', 'originally', 'commonly', 'predominantly']
# cgBERT ['clinched', 'obtained', 'settled', 'garnered', 'won', 'attained', 'scored', 'reached', 'found', 'negotiated']
# cgBERT ['trying', 'beginning', 'seeking', 'preparing', 'about', 'struggling', 'able', 'appearing', 'intending', 'likely']
# cgBERT ['detached', 'parted', 'isolated', 'segregated', 'divorced', 'independent', 'estranged', 'distinct', 'divided', 'distant']
# cgBERT ['generally', 'frequently', 'typically', 'usually', 'often', 'mostly', 'widely', 'popularly', 'notably', 'rarely']
# cgBERT ['pressure', 'expansion', 'acceleration', 'contraction', 'lift', 'gravity', 'deformation', 'stretching', 'force', 'tension']
# cgBERT ['relics', 'objects', 'artifacts', 'parts', 'fragments', 'elements', 'items', 'bones', 'structures', 'images']
# cgBERT ['slowly', 'successively', 'progressively', 'largely', 'steadily', 'eventually', 'generally', 'then', 'systematically', 'mostly']
# cgBERT ['moved', 'displaced', 'removed', 'transitioned', 'migrated', 'returned', 'departed', 'transferred', 'constructed', 'shifted']
# cgBERT ['supposedly', 'variously', 'famously', 'falsely', 'wrongly', 'traditionally', 'allegedly', 'usually', 'sometimes', 'later']
# cgBERT ['decorate', 'restore', 'transform', 'remake', 'paint', 'reform', 'design', 'change', 'prepare', 'create']
# cgBERT ['titled', 'thought', 'regarded', 'deemed', 'called', 'respected', 'recognized', 'recorded', 'believed', 'named']
# cgBERT ['lasted', 'persisted', 'continued', 'endured', 'lived', 'stayed', 'lingered', 'remained', 'last', 'tracked']
# cgBERT ['reaction', 'answer', 'addition', 'submission', 'reply', 'order', 'competition', 'return', 'reference', 'bow']
# cgBERT ['achieved', 'obtained', 'raised', 'scored', 'attained', 'peaked', 'finished', 'made', 'climbed', 'found']
# cgBERT ['founded', 'situated', 'placed', ',', 'resident', 'established', 'determined', 'positioned', 'discovered', 'residing']
# cgBERT ['instance', 'general', 'fact', 'precisely', 'example', 'consequence', 'term', 'namely', 'whole', 'specially']
# cgBERT ['proclaimed', 'termed', 'pronounced', 'announced', 'called', 'deemed', 'designated', 'stated', 'claimed', 'cried']
# cgBERT ['onset', 'commencement', 'commencing', 'start', 'beginning', 'inception', 'first', 'earliest', 'commenced', 'commence']
# cgBERT ['practice', 'occupation', 'discipline', 'career', 'trade', 'hobby', 'specialization', 'ministry', 'method', 'ritual']
# cgBERT ['characteristic', 'typical', 'reflective', 'distinctive', 'customary', 'echoes', 'indicative', 'descriptive', 'derivative', 'those']
# cgBERT ['comprises', 'speaks', 'occurs', 'exists', 'is', 'composed', 'includes', 'originates', 'amounts', 'resides']
# cgBERT ['segments', 'parts', 'quarters', 'areas', 'tracts', 'spheres', 'districts', 'regions', 'neighbourhoods', 'categories']
# 第  1 次循环
# args.prob_mask  0
# The score of evaluation for BERT candidate generation
# 0.982 0.2958 0.23005132991133925 0.25881529442645906
# The score of evaluation for full LS pipeline
# 0.852 0.768 0.916
# end

# %%
import pygame
# 音频初始化
pygame.mixer.init()
# 加载音频文件路径 (路径必须真实存在，音频文件格式支持mp3/ogg等格式)
pygame.mixer.music.load(r'D:/1.mp3')
pygame.mixer.music.play()

# %%
args.prob_mask  0.5
args.seed 5
第  1 次循环
0
cgBERT ['sat', 'hopped', 'landed', 'seated', 'balanced', 'poised', 'crouched', 'braced', 'rested', 'sprawled']
cgBERT ['wrote', 'created', 'published', 'formed', 'constructed', 'collected', 'authored', 'founded', 'formulated', 'scored']
cgBERT ['poems', 'words', 'lyrics', 'pages', 'hymns', 'psalms', 'speeches', 'sections', 'columns', 'lines']
第  1 次循环
args.prob_mask  0.5
The score of evaluation for BERT candidate generation
0.6666666666666666 0.06666666666666667 0.6666666666666666 0.1212121212121212
The score of evaluation for full LS pipeline
0.3333333333333333 0.3333333333333333 1.0
args.seed 15
第  2 次循环
0
cgBERT ['sat', 'hopped', 'landed', 'seated', 'rested', 'braced', 'balanced', 'poised', 'sprawled', 'docked']
cgBERT ['wrote', 'created', 'published', 'authored', 'founded', 'formed', 'written', 'formulated', 'collected', 'called']
cgBERT ['poems', 'words', 'pages', 'lyrics', 'psalms', 'addresses', 'sections', 'speeches', 'hymns', 'parts']
第  2 次循环
args.prob_mask  0.5
The score of evaluation for BERT candidate generation
0.6666666666666666 0.06666666666666667 0.6666666666666666 0.1212121212121212
The score of evaluation for full LS pipeline
0.3333333333333333 0.3333333333333333 1.0
args.seed 25
第  3 次循环
0
cgBERT ['sat', 'hopped', 'landed', 'balanced', 'flew', 'crouched', 'braced', 'sprawled', 'seated', 'nestled']
cgBERT ['wrote', 'created', 'published', 'authored', 'founded', 'formed', 'written', 'formulated', 'collected', 'called']
cgBERT ['poems', 'hymns', 'words', 'pages', 'lyrics', 'psalms', 'sections', 'speeches', 'addresses', 'syllables']
第  3 次循环
args.prob_mask  0.5
The score of evaluation for BERT candidate generation
0.6666666666666666 0.06666666666666667 0.6666666666666666 0.1212121212121212
The score of evaluation for full LS pipeline
0.3333333333333333 0.3333333333333333 1.0
args.seed 35
第  4 次循环
0
cgBERT ['sat', 'hopped', 'landed', 'balanced', 'crouched', 'nestled', 'poised', 'seated', 'sprawled', 'braced']
cgBERT ['wrote', 'created', 'published', 'formed', 'authored', 'founded', 'written', 'collected', 'formulated', 'scored']
cgBERT ['poems', 'words', 'lyrics', 'pages', 'hymns', 'psalms', 'sections', 'chapters', 'speeches', 'addresses']
第  4 次循环
args.prob_mask  0.5
The score of evaluation for BERT candidate generation
0.6666666666666666 0.06666666666666667 0.6666666666666666 0.1212121212121212
The score of evaluation for full LS pipeline
0.3333333333333333 0.3333333333333333 1.0
args.seed 45
第  5 次循环
0
cgBERT ['sat', 'hopped', 'balanced', 'landed', 'nestled', 'crouched', 'poised', 'braced', 'sprawled', 'stood']
cgBERT ['wrote', 'created', 'published', 'formed', 'founded', 'authored', 'formulated', 'collected', 'written', 'called']
cgBERT ['poems', 'words', 'lyrics', 'pages', 'hymns', 'psalms', 'speeches', 'sections', 'columns', 'lines']
第  5 次循环
args.prob_mask  0.5
The score of evaluation for BERT candidate generation
0.6666666666666666 0.06666666666666667 0.6666666666666666 0.1212121212121212
The score of evaluation for full LS pipeline
0.3333333333333333 0.3333333333333333 1.0
end
# Out:
#   File "<ipython-input-23-92dd7976424c>", line 1
#     args.prob_mask  0.5
#                       ^
# SyntaxError: invalid syntax
